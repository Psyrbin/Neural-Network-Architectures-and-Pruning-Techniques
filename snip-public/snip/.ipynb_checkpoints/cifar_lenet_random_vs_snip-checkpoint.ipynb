# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
random_mask = {}
random_mask['w1'] = np.random.choice(2, p=[0.9, 0.1], size=(32*32*3,300)).astype(np.float32)
random_mask['w2'] = np.random.choice(2, p=[0.9, 0.1], size=(300,100)).astype(np.float32)
random_mask['w3'] = np.random.choice(2, p=[0.9, 0.1], size=(100,10)).astype(np.float32)

random_mask['b1'] = np.zeros(300).astype(np.float32)
random_mask['b2'] = np.zeros(100).astype(np.float32)
random_mask['b3'] = np.zeros(10).astype(np.float32)

with open('masks_lenet300_cifar/random_3', 'wb') as f:
    pickle.dump(random_mask, f)

# %%
#0.9
train_random_mask = ['itr100: (train/val) los:2.176/2.158 acc:0.190/0.290 spa:0.900 (t:1.3) \
itr200: (train/val) los:2.025/2.109 acc:0.300/0.220 spa:0.900 (t:1.2) \
itr300: (train/val) los:1.738/1.841 acc:0.430/0.340 spa:0.900 (t:1.2) \
itr400: (train/val) los:1.709/1.862 acc:0.430/0.330 spa:0.900 (t:1.1) \
itr500: (train/val) los:1.733/1.849 acc:0.430/0.410 spa:0.900 (t:1.2) \
itr600: (train/val) los:1.676/1.832 acc:0.470/0.410 spa:0.900 (t:1.2) \
itr700: (train/val) los:1.701/1.577 acc:0.390/0.510 spa:0.900 (t:1.1) \
itr800: (train/val) los:1.663/1.757 acc:0.450/0.330 spa:0.900 (t:1.1) \
itr900: (train/val) los:1.691/1.632 acc:0.400/0.430 spa:0.900 (t:1.2) \
itr1000: (train/val) los:1.518/1.719 acc:0.510/0.420 spa:0.900 (t:1.2) \
itr1100: (train/val) los:1.500/1.355 acc:0.480/0.540 spa:0.900 (t:1.2) \
itr1200: (train/val) los:1.419/1.698 acc:0.550/0.440 spa:0.900 (t:1.2) \
itr1300: (train/val) los:1.506/1.520 acc:0.460/0.470 spa:0.900 (t:1.2) \
itr1400: (train/val) los:1.389/1.587 acc:0.540/0.390 spa:0.900 (t:1.2) \
itr1500: (train/val) los:1.360/1.642 acc:0.580/0.420 spa:0.900 (t:1.2) \
itr1600: (train/val) los:1.499/1.552 acc:0.500/0.440 spa:0.900 (t:1.1) \
itr1700: (train/val) los:1.467/1.689 acc:0.490/0.440 spa:0.900 (t:1.2) \
itr1800: (train/val) los:1.390/1.643 acc:0.550/0.480 spa:0.900 (t:1.2) \
itr1900: (train/val) los:1.440/1.653 acc:0.580/0.470 spa:0.900 (t:1.2) \
itr2000: (train/val) los:1.489/1.712 acc:0.450/0.450 spa:0.900 (t:1.2) \
itr2100: (train/val) los:1.557/1.698 acc:0.460/0.430 spa:0.900 (t:1.2) \
itr2200: (train/val) los:1.499/1.494 acc:0.490/0.440 spa:0.900 (t:1.2) \
itr2300: (train/val) los:1.212/1.405 acc:0.580/0.490 spa:0.900 (t:1.2) \
itr2400: (train/val) los:1.327/1.529 acc:0.520/0.550 spa:0.900 (t:1.2) \
itr2500: (train/val) los:1.398/1.623 acc:0.560/0.380 spa:0.900 (t:1.2) \
itr2600: (train/val) los:1.486/1.593 acc:0.540/0.410 spa:0.900 (t:1.2) \
itr2700: (train/val) los:1.461/1.477 acc:0.500/0.490 spa:0.900 (t:1.2) \
itr2800: (train/val) los:1.521/1.684 acc:0.450/0.430 spa:0.900 (t:1.2) \
itr2900: (train/val) los:1.461/1.402 acc:0.530/0.480 spa:0.900 (t:1.2) \
itr3000: (train/val) los:1.360/1.582 acc:0.540/0.510 spa:0.900 (t:1.2) \
itr3100: (train/val) los:1.273/1.584 acc:0.550/0.410 spa:0.900 (t:1.2) \
itr3200: (train/val) los:1.422/1.559 acc:0.550/0.490 spa:0.900 (t:1.2) \
itr3300: (train/val) los:1.416/1.546 acc:0.550/0.490 spa:0.900 (t:1.2) \
itr3400: (train/val) los:1.362/1.414 acc:0.530/0.530 spa:0.900 (t:1.2) \
itr3500: (train/val) los:1.425/1.533 acc:0.460/0.460 spa:0.900 (t:1.2) \
itr3600: (train/val) los:1.345/1.562 acc:0.550/0.440 spa:0.900 (t:1.2) \
itr3700: (train/val) los:1.268/1.622 acc:0.590/0.450 spa:0.900 (t:1.2) \
itr3800: (train/val) los:1.179/1.446 acc:0.610/0.490 spa:0.900 (t:1.3) \
itr3900: (train/val) los:1.086/1.474 acc:0.640/0.460 spa:0.900 (t:1.3) \
itr4000: (train/val) los:1.226/1.556 acc:0.630/0.490 spa:0.900 (t:1.2) \
itr4100: (train/val) los:1.368/1.555 acc:0.550/0.480 spa:0.900 (t:1.3) \
itr4200: (train/val) los:1.351/1.502 acc:0.500/0.510 spa:0.900 (t:1.3) \
itr4300: (train/val) los:1.336/1.607 acc:0.560/0.470 spa:0.900 (t:1.2) \
itr4400: (train/val) los:1.187/1.696 acc:0.640/0.390 spa:0.900 (t:1.2) \
itr4500: (train/val) los:1.343/1.687 acc:0.520/0.490 spa:0.900 (t:1.2) \
itr4600: (train/val) los:1.224/1.469 acc:0.620/0.540 spa:0.900 (t:1.2) \
itr4700: (train/val) los:1.538/1.622 acc:0.540/0.480 spa:0.900 (t:1.2) \
itr4800: (train/val) los:1.306/1.498 acc:0.560/0.460 spa:0.900 (t:1.2) \
itr4900: (train/val) los:1.370/1.558 acc:0.470/0.520 spa:0.900 (t:1.2) \
itr5000: (train/val) los:1.175/1.350 acc:0.610/0.540 spa:0.900 (t:1.2) \
itr5100: (train/val) los:1.311/1.580 acc:0.560/0.490 spa:0.900 (t:1.2) \
itr5200: (train/val) los:1.406/1.513 acc:0.530/0.470 spa:0.900 (t:1.2) \
itr5300: (train/val) los:1.558/1.863 acc:0.520/0.490 spa:0.900 (t:1.2) \
itr5400: (train/val) los:1.298/1.598 acc:0.610/0.490 spa:0.900 (t:1.2) \
itr5500: (train/val) los:1.161/1.455 acc:0.630/0.460 spa:0.900 (t:1.2) \
itr5600: (train/val) los:1.237/1.533 acc:0.550/0.460 spa:0.900 (t:1.2) \
itr5700: (train/val) los:1.229/1.684 acc:0.530/0.500 spa:0.900 (t:1.2) \
itr5800: (train/val) los:1.082/1.539 acc:0.690/0.490 spa:0.900 (t:1.2) \
itr5900: (train/val) los:1.227/1.805 acc:0.570/0.480 spa:0.900 (t:1.2) \
itr6000: (train/val) los:1.225/1.624 acc:0.580/0.510 spa:0.900 (t:1.2) \
itr6100: (train/val) los:1.100/1.511 acc:0.650/0.500 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.370/1.573 acc:0.620/0.540 spa:0.900 (t:1.2) \
itr6300: (train/val) los:1.412/1.483 acc:0.540/0.550 spa:0.900 (t:1.2) \
itr6400: (train/val) los:1.234/1.566 acc:0.600/0.460 spa:0.900 (t:1.2) \
itr6500: (train/val) los:1.052/1.493 acc:0.660/0.480 spa:0.900 (t:1.2) \
itr6600: (train/val) los:1.245/1.738 acc:0.590/0.440 spa:0.900 (t:1.2) \
itr6700: (train/val) los:1.176/1.732 acc:0.630/0.470 spa:0.900 (t:1.2) \
itr6800: (train/val) los:1.049/1.571 acc:0.700/0.500 spa:0.900 (t:1.2) \
itr6900: (train/val) los:1.167/1.415 acc:0.660/0.590 spa:0.900 (t:1.2) \
itr7000: (train/val) los:1.150/1.538 acc:0.640/0.580 spa:0.900 (t:1.1) \
itr7100: (train/val) los:1.389/1.724 acc:0.560/0.500 spa:0.900 (t:1.2) \
itr7200: (train/val) los:1.183/1.602 acc:0.590/0.510 spa:0.900 (t:1.2) \
itr7300: (train/val) los:1.301/1.705 acc:0.560/0.440 spa:0.900 (t:1.2) \
itr7400: (train/val) los:1.093/1.646 acc:0.670/0.540 spa:0.900 (t:1.2) \
itr7500: (train/val) los:1.040/1.775 acc:0.640/0.410 spa:0.900 (t:1.2) \
itr7600: (train/val) los:1.138/1.625 acc:0.700/0.570 spa:0.900 (t:1.2) \
itr7700: (train/val) los:1.111/1.683 acc:0.630/0.480 spa:0.900 (t:1.2) \
itr7800: (train/val) los:1.093/1.781 acc:0.660/0.410 spa:0.900 (t:1.2) \
itr7900: (train/val) los:0.983/1.505 acc:0.670/0.490 spa:0.900 (t:1.2) \
itr8000: (train/val) los:1.198/1.635 acc:0.600/0.480 spa:0.900 (t:1.1) \
itr8100: (train/val) los:1.097/1.589 acc:0.690/0.450 spa:0.900 (t:1.2) \
itr8200: (train/val) los:1.128/1.853 acc:0.610/0.410 spa:0.900 (t:1.2) \
itr8300: (train/val) los:1.276/1.482 acc:0.630/0.550 spa:0.900 (t:1.2) \
itr8400: (train/val) los:1.159/1.496 acc:0.690/0.510 spa:0.900 (t:1.1) \
itr8500: (train/val) los:1.138/1.705 acc:0.630/0.410 spa:0.900 (t:1.1) \
itr8600: (train/val) los:0.999/1.305 acc:0.680/0.570 spa:0.900 (t:1.2) \
itr8700: (train/val) los:1.112/1.726 acc:0.670/0.480 spa:0.900 (t:1.2) \
itr8800: (train/val) los:1.073/1.712 acc:0.680/0.480 spa:0.900 (t:1.3) \
itr8900: (train/val) los:1.218/1.887 acc:0.610/0.410 spa:0.900 (t:1.2) \
itr9000: (train/val) los:1.110/1.603 acc:0.600/0.490 spa:0.900 (t:1.2) \
itr9100: (train/val) los:1.275/1.618 acc:0.630/0.460 spa:0.900 (t:1.3) \
itr9200: (train/val) los:1.237/1.574 acc:0.610/0.460 spa:0.900 (t:1.2) \
itr9300: (train/val) los:1.293/1.868 acc:0.610/0.410 spa:0.900 (t:1.2) \
itr9400: (train/val) los:1.145/1.655 acc:0.620/0.500 spa:0.900 (t:1.2) \
itr9500: (train/val) los:1.069/1.788 acc:0.630/0.460 spa:0.900 (t:1.2) \
itr9600: (train/val) los:1.177/1.786 acc:0.650/0.490 spa:0.900 (t:1.2) \
itr9700: (train/val) los:1.160/1.730 acc:0.620/0.490 spa:0.900 (t:1.2) \
itr9800: (train/val) los:1.010/1.687 acc:0.670/0.530 spa:0.900 (t:1.2) \
itr9900: (train/val) los:1.037/1.492 acc:0.710/0.500 spa:0.900 (t:1.2) \
itr10000: (train/val) los:0.921/1.577 acc:0.770/0.510 spa:0.900 (t:1.2)',
'itr100: (train/val) los:2.194/2.209 acc:0.230/0.210 spa:0.900 (t:1.3) \
itr200: (train/val) los:2.062/2.165 acc:0.260/0.280 spa:0.900 (t:1.2) \
itr300: (train/val) los:1.815/1.914 acc:0.370/0.300 spa:0.900 (t:1.2) \
itr400: (train/val) los:1.720/1.879 acc:0.420/0.310 spa:0.900 (t:1.2) \
itr500: (train/val) los:1.767/1.908 acc:0.370/0.290 spa:0.900 (t:1.2) \
itr600: (train/val) los:1.669/1.862 acc:0.510/0.410 spa:0.900 (t:1.2) \
itr700: (train/val) los:1.725/1.559 acc:0.450/0.490 spa:0.900 (t:1.2) \
itr800: (train/val) los:1.685/1.831 acc:0.450/0.320 spa:0.900 (t:1.2) \
itr900: (train/val) los:1.762/1.688 acc:0.420/0.420 spa:0.900 (t:1.2) \
itr1000: (train/val) los:1.580/1.687 acc:0.460/0.460 spa:0.900 (t:1.2) \
itr1100: (train/val) los:1.516/1.430 acc:0.490/0.500 spa:0.900 (t:1.2) \
itr1200: (train/val) los:1.436/1.703 acc:0.530/0.420 spa:0.900 (t:1.2) \
itr1300: (train/val) los:1.485/1.556 acc:0.440/0.450 spa:0.900 (t:1.2) \
itr1400: (train/val) los:1.383/1.617 acc:0.530/0.370 spa:0.900 (t:1.2) \
itr1500: (train/val) los:1.433/1.669 acc:0.500/0.440 spa:0.900 (t:1.2) \
itr1600: (train/val) los:1.553/1.559 acc:0.520/0.490 spa:0.900 (t:1.2) \
itr1700: (train/val) los:1.511/1.701 acc:0.490/0.380 spa:0.900 (t:1.2) \
itr1800: (train/val) los:1.391/1.598 acc:0.540/0.510 spa:0.900 (t:1.2) \
itr1900: (train/val) los:1.508/1.679 acc:0.560/0.400 spa:0.900 (t:1.2) \
itr2000: (train/val) los:1.516/1.836 acc:0.400/0.410 spa:0.900 (t:1.2) \
itr2100: (train/val) los:1.530/1.707 acc:0.500/0.420 spa:0.900 (t:1.2) \
itr2200: (train/val) los:1.515/1.463 acc:0.480/0.520 spa:0.900 (t:1.2) \
itr2300: (train/val) los:1.229/1.393 acc:0.620/0.510 spa:0.900 (t:1.2) \
itr2400: (train/val) los:1.386/1.561 acc:0.540/0.540 spa:0.900 (t:1.2) \
itr2500: (train/val) los:1.433/1.655 acc:0.530/0.350 spa:0.900 (t:1.2) \
itr2600: (train/val) los:1.448/1.612 acc:0.550/0.370 spa:0.900 (t:1.2) \
itr2700: (train/val) los:1.487/1.380 acc:0.520/0.570 spa:0.900 (t:1.2) \
itr2800: (train/val) los:1.374/1.703 acc:0.450/0.370 spa:0.900 (t:1.2) \
itr2900: (train/val) los:1.485/1.449 acc:0.480/0.470 spa:0.900 (t:1.2) \
itr3000: (train/val) los:1.419/1.580 acc:0.570/0.530 spa:0.900 (t:1.2) \
itr3100: (train/val) los:1.365/1.667 acc:0.510/0.400 spa:0.900 (t:1.2) \
itr3200: (train/val) los:1.438/1.669 acc:0.490/0.480 spa:0.900 (t:1.2) \
itr3300: (train/val) los:1.481/1.580 acc:0.520/0.500 spa:0.900 (t:1.2) \
itr3400: (train/val) los:1.476/1.454 acc:0.500/0.510 spa:0.900 (t:1.2) \
itr3500: (train/val) los:1.408/1.604 acc:0.540/0.470 spa:0.900 (t:1.2) \
itr3600: (train/val) los:1.333/1.585 acc:0.580/0.460 spa:0.900 (t:1.2) \
itr3700: (train/val) los:1.271/1.664 acc:0.570/0.430 spa:0.900 (t:1.2) \
itr3800: (train/val) los:1.192/1.394 acc:0.590/0.520 spa:0.900 (t:1.2) \
itr3900: (train/val) los:1.128/1.442 acc:0.580/0.500 spa:0.900 (t:1.2) \
itr4000: (train/val) los:1.275/1.514 acc:0.580/0.490 spa:0.900 (t:1.2) \
itr4100: (train/val) los:1.364/1.525 acc:0.560/0.510 spa:0.900 (t:1.2) \
itr4200: (train/val) los:1.324/1.546 acc:0.530/0.500 spa:0.900 (t:1.2) \
itr4300: (train/val) los:1.211/1.581 acc:0.600/0.460 spa:0.900 (t:1.2) \
itr4400: (train/val) los:1.268/1.742 acc:0.590/0.470 spa:0.900 (t:1.2) \
itr4500: (train/val) los:1.256/1.800 acc:0.560/0.390 spa:0.900 (t:1.2) \
itr4600: (train/val) los:1.316/1.503 acc:0.570/0.490 spa:0.900 (t:1.2) \
itr4700: (train/val) los:1.457/1.557 acc:0.540/0.510 spa:0.900 (t:1.2) \
itr4800: (train/val) los:1.253/1.439 acc:0.610/0.490 spa:0.900 (t:1.2) \
itr4900: (train/val) los:1.399/1.621 acc:0.490/0.520 spa:0.900 (t:1.2) \
itr5000: (train/val) los:1.219/1.345 acc:0.560/0.570 spa:0.900 (t:1.2) \
itr5100: (train/val) los:1.294/1.455 acc:0.600/0.520 spa:0.900 (t:1.2) \
itr5200: (train/val) los:1.379/1.619 acc:0.520/0.450 spa:0.900 (t:1.2) \
itr5300: (train/val) los:1.588/1.810 acc:0.580/0.430 spa:0.900 (t:1.2) \
itr5400: (train/val) los:1.314/1.661 acc:0.580/0.450 spa:0.900 (t:1.2) \
itr5500: (train/val) los:1.316/1.410 acc:0.580/0.510 spa:0.900 (t:1.2) \
itr5600: (train/val) los:1.336/1.459 acc:0.630/0.480 spa:0.900 (t:1.2) \
itr5700: (train/val) los:1.159/1.861 acc:0.650/0.440 spa:0.900 (t:1.2) \
itr5800: (train/val) los:1.140/1.504 acc:0.650/0.480 spa:0.900 (t:1.2) \
itr5900: (train/val) los:1.292/1.806 acc:0.560/0.470 spa:0.900 (t:1.2) \
itr6000: (train/val) los:1.216/1.684 acc:0.600/0.510 spa:0.900 (t:1.2) \
itr6100: (train/val) los:1.031/1.593 acc:0.620/0.510 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.463/1.472 acc:0.530/0.510 spa:0.900 (t:1.1) \
itr6300: (train/val) los:1.335/1.571 acc:0.560/0.510 spa:0.900 (t:1.1) \
itr6400: (train/val) los:1.244/1.528 acc:0.580/0.510 spa:0.900 (t:1.2) \
itr6500: (train/val) los:1.109/1.549 acc:0.650/0.460 spa:0.900 (t:1.2) \
itr6600: (train/val) los:1.239/1.556 acc:0.630/0.460 spa:0.900 (t:1.2) \
itr6700: (train/val) los:1.229/1.722 acc:0.610/0.440 spa:0.900 (t:1.2) \
itr6800: (train/val) los:1.072/1.438 acc:0.660/0.500 spa:0.900 (t:1.2) \
itr6900: (train/val) los:1.239/1.499 acc:0.640/0.520 spa:0.900 (t:1.2) \
itr7000: (train/val) los:1.145/1.539 acc:0.660/0.510 spa:0.900 (t:1.2) \
itr7100: (train/val) los:1.346/1.594 acc:0.550/0.570 spa:0.900 (t:1.2) \
itr7200: (train/val) los:1.181/1.635 acc:0.650/0.530 spa:0.900 (t:1.2) \
itr7300: (train/val) los:1.206/1.779 acc:0.570/0.470 spa:0.900 (t:1.2) \
itr7400: (train/val) los:1.101/1.540 acc:0.690/0.550 spa:0.900 (t:1.2) \
itr7500: (train/val) los:1.090/1.929 acc:0.620/0.440 spa:0.900 (t:1.2) \
itr7600: (train/val) los:1.177/1.714 acc:0.670/0.560 spa:0.900 (t:1.2) \
itr7700: (train/val) los:1.136/1.736 acc:0.610/0.490 spa:0.900 (t:1.2) \
itr7800: (train/val) los:1.106/1.723 acc:0.650/0.450 spa:0.900 (t:1.2) \
itr7900: (train/val) los:0.979/1.541 acc:0.700/0.480 spa:0.900 (t:1.2) \
itr8000: (train/val) los:1.224/1.809 acc:0.520/0.420 spa:0.900 (t:1.2) \
itr8100: (train/val) los:1.100/1.652 acc:0.680/0.490 spa:0.900 (t:1.2) \
itr8200: (train/val) los:1.145/1.856 acc:0.630/0.410 spa:0.900 (t:1.2) \
itr8300: (train/val) los:1.215/1.526 acc:0.620/0.560 spa:0.900 (t:1.2) \
itr8400: (train/val) los:1.227/1.595 acc:0.610/0.530 spa:0.900 (t:1.2) \
itr8500: (train/val) los:1.012/1.780 acc:0.700/0.440 spa:0.900 (t:1.2) \
itr8600: (train/val) los:1.052/1.541 acc:0.610/0.500 spa:0.900 (t:1.2) \
itr8700: (train/val) los:1.130/2.024 acc:0.650/0.430 spa:0.900 (t:1.2) \
itr8800: (train/val) los:1.186/1.588 acc:0.600/0.540 spa:0.900 (t:1.2) \
itr8900: (train/val) los:1.180/1.877 acc:0.660/0.420 spa:0.900 (t:1.2) \
itr9000: (train/val) los:1.232/1.962 acc:0.580/0.430 spa:0.900 (t:1.2) \
itr9100: (train/val) los:1.167/1.639 acc:0.580/0.530 spa:0.900 (t:1.2) \
itr9200: (train/val) los:1.221/1.602 acc:0.610/0.500 spa:0.900 (t:1.2) \
itr9300: (train/val) los:1.277/1.724 acc:0.620/0.460 spa:0.900 (t:1.2) \
itr9400: (train/val) los:1.172/1.638 acc:0.590/0.490 spa:0.900 (t:1.2) \
itr9500: (train/val) los:1.127/1.690 acc:0.630/0.510 spa:0.900 (t:1.2) \
itr9600: (train/val) los:1.202/1.814 acc:0.570/0.480 spa:0.900 (t:1.2) \
itr9700: (train/val) los:1.151/1.767 acc:0.640/0.570 spa:0.900 (t:1.2) \
itr9800: (train/val) los:1.036/1.798 acc:0.690/0.490 spa:0.900 (t:1.2) \
itr9900: (train/val) los:0.957/1.647 acc:0.740/0.470 spa:0.900 (t:1.2) \
itr10000: (train/val) los:1.159/1.725 acc:0.670/0.500 spa:0.900 (t:1.2)',
'itr100: (train/val) los:2.160/2.170 acc:0.290/0.310 spa:0.900 (t:1.3) \
itr200: (train/val) los:2.052/2.110 acc:0.270/0.210 spa:0.900 (t:1.2) \
itr300: (train/val) los:1.808/1.896 acc:0.350/0.300 spa:0.900 (t:1.2) \
itr400: (train/val) los:1.754/1.926 acc:0.400/0.280 spa:0.900 (t:1.2) \
itr500: (train/val) los:1.770/1.905 acc:0.420/0.360 spa:0.900 (t:1.2) \
itr600: (train/val) los:1.626/1.836 acc:0.480/0.410 spa:0.900 (t:1.1) \
itr700: (train/val) los:1.729/1.598 acc:0.420/0.470 spa:0.900 (t:1.2) \
itr800: (train/val) los:1.710/1.829 acc:0.440/0.320 spa:0.900 (t:1.2) \
itr900: (train/val) los:1.749/1.706 acc:0.350/0.390 spa:0.900 (t:1.2) \
itr1000: (train/val) los:1.521/1.687 acc:0.500/0.430 spa:0.900 (t:1.2) \
itr1100: (train/val) los:1.528/1.403 acc:0.510/0.520 spa:0.900 (t:1.2) \
itr1200: (train/val) los:1.396/1.656 acc:0.510/0.410 spa:0.900 (t:1.2) \
itr1300: (train/val) los:1.518/1.544 acc:0.460/0.480 spa:0.900 (t:1.3) \
itr1400: (train/val) los:1.435/1.572 acc:0.500/0.400 spa:0.900 (t:1.4) \
itr1500: (train/val) los:1.352/1.638 acc:0.550/0.430 spa:0.900 (t:1.4) \
itr1600: (train/val) los:1.535/1.593 acc:0.480/0.440 spa:0.900 (t:1.2) \
itr1700: (train/val) los:1.501/1.714 acc:0.460/0.400 spa:0.900 (t:1.2) \
itr1800: (train/val) los:1.315/1.604 acc:0.590/0.540 spa:0.900 (t:1.2) \
itr1900: (train/val) los:1.456/1.633 acc:0.560/0.440 spa:0.900 (t:1.2) \
itr2000: (train/val) los:1.452/1.679 acc:0.470/0.470 spa:0.900 (t:1.2) \
itr2100: (train/val) los:1.574/1.760 acc:0.500/0.400 spa:0.900 (t:1.2) \
itr2200: (train/val) los:1.497/1.455 acc:0.480/0.530 spa:0.900 (t:1.2) \
itr2300: (train/val) los:1.220/1.375 acc:0.580/0.530 spa:0.900 (t:1.2) \
itr2400: (train/val) los:1.412/1.517 acc:0.510/0.560 spa:0.900 (t:1.2) \
itr2500: (train/val) los:1.383/1.683 acc:0.580/0.390 spa:0.900 (t:1.2) \
itr2600: (train/val) los:1.435/1.621 acc:0.580/0.340 spa:0.900 (t:1.2) \
itr2700: (train/val) los:1.421/1.492 acc:0.520/0.510 spa:0.900 (t:1.2) \
itr2800: (train/val) los:1.449/1.672 acc:0.450/0.480 spa:0.900 (t:1.3) \
itr2900: (train/val) los:1.450/1.424 acc:0.520/0.500 spa:0.900 (t:1.3) \
itr3000: (train/val) los:1.406/1.644 acc:0.550/0.430 spa:0.900 (t:1.3) \
itr3100: (train/val) los:1.336/1.585 acc:0.570/0.430 spa:0.900 (t:1.4) \
itr3200: (train/val) los:1.426/1.627 acc:0.500/0.460 spa:0.900 (t:1.3) \
itr3300: (train/val) los:1.474/1.567 acc:0.530/0.490 spa:0.900 (t:1.2) \
itr3400: (train/val) los:1.402/1.434 acc:0.520/0.500 spa:0.900 (t:1.2) \
itr3500: (train/val) los:1.428/1.500 acc:0.510/0.500 spa:0.900 (t:1.2) \
itr3600: (train/val) los:1.309/1.645 acc:0.570/0.420 spa:0.900 (t:1.2) \
itr3700: (train/val) los:1.333/1.739 acc:0.590/0.440 spa:0.900 (t:1.2) \
itr3800: (train/val) los:1.213/1.494 acc:0.560/0.460 spa:0.900 (t:1.2) \
itr3900: (train/val) los:1.141/1.434 acc:0.610/0.500 spa:0.900 (t:1.2) \
itr4000: (train/val) los:1.264/1.562 acc:0.600/0.480 spa:0.900 (t:1.2) \
itr4100: (train/val) los:1.387/1.476 acc:0.550/0.480 spa:0.900 (t:1.3) \
itr4200: (train/val) los:1.355/1.441 acc:0.510/0.510 spa:0.900 (t:1.2) \
itr4300: (train/val) los:1.289/1.638 acc:0.510/0.540 spa:0.900 (t:1.2) \
itr4400: (train/val) los:1.167/1.776 acc:0.630/0.420 spa:0.900 (t:1.2) \
itr4500: (train/val) los:1.285/1.698 acc:0.550/0.430 spa:0.900 (t:1.2) \
itr4600: (train/val) los:1.278/1.369 acc:0.600/0.520 spa:0.900 (t:1.2) \
itr4700: (train/val) los:1.448/1.634 acc:0.560/0.480 spa:0.900 (t:1.2) \
itr4800: (train/val) los:1.336/1.442 acc:0.520/0.550 spa:0.900 (t:1.2) \
itr4900: (train/val) los:1.355/1.456 acc:0.530/0.490 spa:0.900 (t:1.2) \
itr5000: (train/val) los:1.241/1.361 acc:0.540/0.580 spa:0.900 (t:1.2) \
itr5100: (train/val) los:1.274/1.441 acc:0.630/0.550 spa:0.900 (t:1.2) \
itr5200: (train/val) los:1.417/1.495 acc:0.530/0.450 spa:0.900 (t:1.2) \
itr5300: (train/val) los:1.522/1.828 acc:0.600/0.490 spa:0.900 (t:1.2) \
itr5400: (train/val) los:1.301/1.649 acc:0.610/0.500 spa:0.900 (t:1.2) \
itr5500: (train/val) los:1.393/1.426 acc:0.540/0.490 spa:0.900 (t:1.2) \
itr5600: (train/val) los:1.269/1.524 acc:0.610/0.510 spa:0.900 (t:1.2) \
itr5700: (train/val) los:1.277/1.683 acc:0.590/0.470 spa:0.900 (t:1.2) \
itr5800: (train/val) los:1.055/1.555 acc:0.710/0.480 spa:0.900 (t:1.2) \
itr5900: (train/val) los:1.290/1.777 acc:0.560/0.490 spa:0.900 (t:1.2) \
itr6000: (train/val) los:1.175/1.621 acc:0.610/0.490 spa:0.900 (t:1.2) \
itr6100: (train/val) los:1.051/1.643 acc:0.650/0.500 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.376/1.483 acc:0.590/0.540 spa:0.900 (t:1.2) \
itr6300: (train/val) los:1.351/1.523 acc:0.560/0.550 spa:0.900 (t:1.2) \
itr6400: (train/val) los:1.191/1.485 acc:0.590/0.500 spa:0.900 (t:1.2) \
itr6500: (train/val) los:1.074/1.609 acc:0.680/0.450 spa:0.900 (t:1.2) \
itr6600: (train/val) los:1.202/1.658 acc:0.620/0.470 spa:0.900 (t:1.2) \
itr6700: (train/val) los:1.265/1.601 acc:0.610/0.450 spa:0.900 (t:1.2) \
itr6800: (train/val) los:1.100/1.482 acc:0.670/0.560 spa:0.900 (t:1.2) \
itr6900: (train/val) los:1.133/1.465 acc:0.640/0.550 spa:0.900 (t:1.2) \
itr7000: (train/val) los:1.104/1.477 acc:0.640/0.610 spa:0.900 (t:1.2) \
itr7100: (train/val) los:1.319/1.653 acc:0.550/0.500 spa:0.900 (t:1.2) \
itr7200: (train/val) los:1.201/1.632 acc:0.620/0.480 spa:0.900 (t:1.2) \
itr7300: (train/val) los:1.219/1.731 acc:0.600/0.400 spa:0.900 (t:1.2) \
itr7400: (train/val) los:1.044/1.577 acc:0.700/0.540 spa:0.900 (t:1.2) \
itr7500: (train/val) los:0.959/1.712 acc:0.690/0.460 spa:0.900 (t:1.2) \
itr7600: (train/val) los:1.206/1.634 acc:0.690/0.540 spa:0.900 (t:1.2) \
itr7700: (train/val) los:1.123/1.813 acc:0.640/0.410 spa:0.900 (t:1.2) \
itr7800: (train/val) los:1.068/1.675 acc:0.610/0.470 spa:0.900 (t:1.2) \
itr7900: (train/val) los:1.055/1.541 acc:0.710/0.440 spa:0.900 (t:1.2) \
itr8000: (train/val) los:1.214/1.745 acc:0.620/0.420 spa:0.900 (t:1.2) \
itr8100: (train/val) los:1.202/1.648 acc:0.680/0.490 spa:0.900 (t:1.2) \
itr8200: (train/val) los:1.115/1.806 acc:0.620/0.380 spa:0.900 (t:1.2) \
itr8300: (train/val) los:1.215/1.402 acc:0.620/0.540 spa:0.900 (t:1.2) \
itr8400: (train/val) los:1.012/1.558 acc:0.690/0.510 spa:0.900 (t:1.2) \
itr8500: (train/val) los:1.055/1.780 acc:0.660/0.450 spa:0.900 (t:1.2) \
itr8600: (train/val) los:0.946/1.408 acc:0.730/0.590 spa:0.900 (t:1.2) \
itr8700: (train/val) los:1.115/1.864 acc:0.680/0.470 spa:0.900 (t:1.3) \
itr8800: (train/val) los:1.040/1.561 acc:0.720/0.540 spa:0.900 (t:1.4) \
itr8900: (train/val) los:1.236/1.833 acc:0.600/0.470 spa:0.900 (t:1.3) \
itr9000: (train/val) los:1.221/1.809 acc:0.590/0.480 spa:0.900 (t:1.2) \
itr9100: (train/val) los:1.119/1.745 acc:0.630/0.430 spa:0.900 (t:1.3) \
itr9200: (train/val) los:1.223/1.671 acc:0.560/0.530 spa:0.900 (t:1.2) \
itr9300: (train/val) los:1.213/1.763 acc:0.630/0.410 spa:0.900 (t:1.2) \
itr9400: (train/val) los:1.207/1.446 acc:0.580/0.560 spa:0.900 (t:1.2) \
itr9500: (train/val) los:1.145/1.794 acc:0.580/0.510 spa:0.900 (t:1.2) \
itr9600: (train/val) los:1.184/1.690 acc:0.590/0.470 spa:0.900 (t:1.2) \
itr9700: (train/val) los:1.122/1.819 acc:0.620/0.440 spa:0.900 (t:1.2) \
itr9800: (train/val) los:1.212/1.697 acc:0.610/0.550 spa:0.900 (t:1.2) \
itr9900: (train/val) los:1.081/1.598 acc:0.620/0.530 spa:0.900 (t:1.2) \
itr10000: (train/val) los:1.056/1.725 acc:0.660/0.510 spa:0.900 (t:1.2)']

# %%
#0.9
train_snip_mask = ['itr100: (train/val) los:1.985/1.817 acc:0.320/0.330 spa:0.900 (t:1.2) \
itr200: (train/val) los:1.733/1.908 acc:0.450/0.370 spa:0.900 (t:1.2) \
itr300: (train/val) los:1.617/1.668 acc:0.400/0.420 spa:0.900 (t:1.1) \
itr400: (train/val) los:1.704/1.756 acc:0.380/0.380 spa:0.900 (t:1.2) \
itr500: (train/val) los:1.563/1.693 acc:0.480/0.500 spa:0.900 (t:1.2) \
itr600: (train/val) los:1.762/1.852 acc:0.370/0.390 spa:0.900 (t:1.1) \
itr700: (train/val) los:1.460/1.461 acc:0.580/0.460 spa:0.900 (t:1.1) \
itr800: (train/val) los:1.700/1.758 acc:0.440/0.370 spa:0.900 (t:1.1) \
itr900: (train/val) los:1.542/1.597 acc:0.420/0.420 spa:0.900 (t:1.1) \
itr1000: (train/val) los:1.564/1.732 acc:0.480/0.450 spa:0.900 (t:1.2) \
itr1100: (train/val) los:1.398/1.306 acc:0.530/0.570 spa:0.900 (t:1.2) \
itr1200: (train/val) los:1.498/1.695 acc:0.470/0.500 spa:0.900 (t:1.2) \
itr1300: (train/val) los:1.448/1.474 acc:0.510/0.490 spa:0.900 (t:1.2) \
itr1400: (train/val) los:1.246/1.585 acc:0.560/0.400 spa:0.900 (t:1.1) \
itr1500: (train/val) los:1.541/1.526 acc:0.520/0.450 spa:0.900 (t:1.1) \
itr1600: (train/val) los:1.460/1.611 acc:0.550/0.440 spa:0.900 (t:1.2) \
itr1700: (train/val) los:1.413/1.647 acc:0.500/0.390 spa:0.900 (t:1.1) \
itr1800: (train/val) los:1.456/1.519 acc:0.490/0.510 spa:0.900 (t:1.2) \
itr1900: (train/val) los:1.532/1.727 acc:0.470/0.410 spa:0.900 (t:1.2) \
itr2000: (train/val) los:1.448/1.641 acc:0.530/0.460 spa:0.900 (t:1.1) \
itr2100: (train/val) los:1.456/1.663 acc:0.500/0.440 spa:0.900 (t:1.3) \
itr2200: (train/val) los:1.407/1.464 acc:0.540/0.500 spa:0.900 (t:1.1) \
itr2300: (train/val) los:1.483/1.370 acc:0.520/0.560 spa:0.900 (t:1.3) \
itr2400: (train/val) los:1.260/1.422 acc:0.580/0.580 spa:0.900 (t:1.2) \
itr2500: (train/val) los:1.459/1.633 acc:0.490/0.420 spa:0.900 (t:1.1) \
itr2600: (train/val) los:1.457/1.574 acc:0.510/0.490 spa:0.900 (t:1.1) \
itr2700: (train/val) los:1.362/1.555 acc:0.540/0.500 spa:0.900 (t:1.1) \
itr2800: (train/val) los:1.238/1.678 acc:0.550/0.370 spa:0.900 (t:1.1) \
itr2900: (train/val) los:1.465/1.392 acc:0.540/0.490 spa:0.900 (t:1.1) \
itr3000: (train/val) los:1.458/1.392 acc:0.530/0.600 spa:0.900 (t:1.2) \
itr3100: (train/val) los:1.292/1.617 acc:0.590/0.450 spa:0.900 (t:1.3) \
itr3200: (train/val) los:1.364/1.591 acc:0.520/0.470 spa:0.900 (t:1.1) \
itr3300: (train/val) los:1.042/1.495 acc:0.590/0.450 spa:0.900 (t:1.2) \
itr3400: (train/val) los:1.458/1.382 acc:0.500/0.530 spa:0.900 (t:1.2) \
itr3500: (train/val) los:1.309/1.561 acc:0.580/0.450 spa:0.900 (t:1.1) \
itr3600: (train/val) los:1.156/1.619 acc:0.630/0.410 spa:0.900 (t:1.2) \
itr3700: (train/val) los:1.187/1.713 acc:0.590/0.450 spa:0.900 (t:1.1) \
itr3800: (train/val) los:1.469/1.326 acc:0.520/0.580 spa:0.900 (t:1.1) \
itr3900: (train/val) los:1.289/1.536 acc:0.560/0.480 spa:0.900 (t:1.1) \
itr4000: (train/val) los:1.275/1.545 acc:0.570/0.490 spa:0.900 (t:1.3) \
itr4100: (train/val) los:1.655/1.435 acc:0.450/0.530 spa:0.900 (t:1.3) \
itr4200: (train/val) los:1.539/1.459 acc:0.500/0.500 spa:0.900 (t:1.2) \
itr4300: (train/val) los:1.374/1.559 acc:0.480/0.520 spa:0.900 (t:1.2) \
itr4400: (train/val) los:1.513/1.684 acc:0.450/0.450 spa:0.900 (t:1.2) \
itr4500: (train/val) los:1.240/1.786 acc:0.580/0.380 spa:0.900 (t:1.1) \
itr4600: (train/val) los:1.277/1.363 acc:0.590/0.550 spa:0.900 (t:1.2) \
itr4700: (train/val) los:1.139/1.569 acc:0.550/0.580 spa:0.900 (t:1.1) \
itr4800: (train/val) los:1.094/1.378 acc:0.660/0.510 spa:0.900 (t:1.1) \
itr4900: (train/val) los:1.230/1.414 acc:0.530/0.470 spa:0.900 (t:1.2) \
itr5000: (train/val) los:1.094/1.285 acc:0.620/0.580 spa:0.900 (t:1.2) \
itr5100: (train/val) los:1.141/1.377 acc:0.590/0.580 spa:0.900 (t:1.3) \
itr5200: (train/val) los:1.247/1.549 acc:0.560/0.420 spa:0.900 (t:1.2) \
itr5300: (train/val) los:1.210/1.764 acc:0.570/0.470 spa:0.900 (t:1.2) \
itr5400: (train/val) los:1.105/1.446 acc:0.620/0.510 spa:0.900 (t:1.2) \
itr5500: (train/val) los:1.166/1.384 acc:0.620/0.510 spa:0.900 (t:1.1) \
itr5600: (train/val) los:1.179/1.369 acc:0.580/0.570 spa:0.900 (t:1.1) \
itr5700: (train/val) los:1.189/1.626 acc:0.580/0.480 spa:0.900 (t:1.2) \
itr5800: (train/val) los:1.016/1.525 acc:0.650/0.460 spa:0.900 (t:1.1) \
itr5900: (train/val) los:1.111/1.861 acc:0.690/0.380 spa:0.900 (t:1.1) \
itr6000: (train/val) los:1.149/1.434 acc:0.610/0.590 spa:0.900 (t:1.1) \
itr6100: (train/val) los:1.007/1.498 acc:0.600/0.570 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.241/1.428 acc:0.570/0.560 spa:0.900 (t:1.1) \
itr6300: (train/val) los:1.314/1.444 acc:0.530/0.500 spa:0.900 (t:1.1) \
itr6400: (train/val) los:1.232/1.452 acc:0.580/0.530 spa:0.900 (t:1.1) \
itr6500: (train/val) los:1.118/1.490 acc:0.690/0.470 spa:0.900 (t:1.1) \
itr6600: (train/val) los:1.352/1.526 acc:0.540/0.460 spa:0.900 (t:1.2) \
itr6700: (train/val) los:1.213/1.561 acc:0.610/0.450 spa:0.900 (t:1.1) \
itr6800: (train/val) los:1.131/1.335 acc:0.680/0.590 spa:0.900 (t:1.2) \
itr6900: (train/val) los:1.056/1.517 acc:0.630/0.550 spa:0.900 (t:1.1) \
itr7000: (train/val) los:1.141/1.447 acc:0.600/0.520 spa:0.900 (t:1.2) \
itr7100: (train/val) los:1.287/1.545 acc:0.620/0.550 spa:0.900 (t:1.2) \
itr7200: (train/val) los:0.975/1.547 acc:0.700/0.470 spa:0.900 (t:1.2) \
itr7300: (train/val) los:1.218/1.683 acc:0.610/0.500 spa:0.900 (t:1.1) \
itr7400: (train/val) los:1.183/1.487 acc:0.640/0.620 spa:0.900 (t:1.1) \
itr7500: (train/val) los:1.150/1.817 acc:0.640/0.450 spa:0.900 (t:1.2) \
itr7600: (train/val) los:1.048/1.458 acc:0.680/0.550 spa:0.900 (t:1.1) \
itr7700: (train/val) los:0.996/1.620 acc:0.680/0.470 spa:0.900 (t:1.3) \
itr7800: (train/val) los:1.042/1.635 acc:0.680/0.490 spa:0.900 (t:1.2) \
itr7900: (train/val) los:1.162/1.419 acc:0.600/0.490 spa:0.900 (t:1.2) \
itr8000: (train/val) los:1.075/1.660 acc:0.630/0.510 spa:0.900 (t:1.1) \
itr8100: (train/val) los:0.878/1.512 acc:0.720/0.510 spa:0.900 (t:1.3) \
itr8200: (train/val) los:1.122/1.749 acc:0.650/0.430 spa:0.900 (t:1.2) \
itr8300: (train/val) los:1.147/1.446 acc:0.600/0.560 spa:0.900 (t:1.1) \
itr8400: (train/val) los:1.280/1.433 acc:0.600/0.580 spa:0.900 (t:1.1) \
itr8500: (train/val) los:1.118/1.553 acc:0.630/0.470 spa:0.900 (t:1.1) \
itr8600: (train/val) los:1.196/1.356 acc:0.670/0.500 spa:0.900 (t:1.1) \
itr8700: (train/val) los:0.966/1.554 acc:0.710/0.540 spa:0.900 (t:1.1) \
itr8800: (train/val) los:0.964/1.476 acc:0.660/0.550 spa:0.900 (t:1.1) \
itr8900: (train/val) los:1.113/1.817 acc:0.620/0.430 spa:0.900 (t:1.1) \
itr9000: (train/val) los:1.143/1.609 acc:0.590/0.470 spa:0.900 (t:1.1) \
itr9100: (train/val) los:0.925/1.675 acc:0.670/0.460 spa:0.900 (t:1.2) \
itr9200: (train/val) los:1.053/1.548 acc:0.650/0.510 spa:0.900 (t:1.1) \
itr9300: (train/val) los:1.102/1.637 acc:0.700/0.470 spa:0.900 (t:1.1) \
itr9400: (train/val) los:1.063/1.704 acc:0.620/0.480 spa:0.900 (t:1.2) \
itr9500: (train/val) los:1.089/1.534 acc:0.630/0.630 spa:0.900 (t:1.2) \
itr9600: (train/val) los:1.102/1.490 acc:0.600/0.550 spa:0.900 (t:1.2) \
itr9700: (train/val) los:1.082/1.676 acc:0.650/0.560 spa:0.900 (t:1.2) \
itr9800: (train/val) los:1.039/1.703 acc:0.670/0.470 spa:0.900 (t:1.1) \
itr9900: (train/val) los:1.208/1.558 acc:0.580/0.500 spa:0.900 (t:1.1) \
itr10000: (train/val) los:1.249/1.688 acc:0.620/0.510 spa:0.900 (t:1.1)',
'itr100: (train/val) los:2.003/1.868 acc:0.380/0.310 spa:0.900 (t:1.3) \
itr200: (train/val) los:1.731/1.938 acc:0.420/0.360 spa:0.900 (t:1.1) \
itr300: (train/val) los:1.709/1.723 acc:0.310/0.360 spa:0.900 (t:1.2) \
itr400: (train/val) los:1.728/1.734 acc:0.400/0.320 spa:0.900 (t:1.1) \
itr500: (train/val) los:1.589/1.808 acc:0.480/0.400 spa:0.900 (t:1.1) \
itr600: (train/val) los:1.710/1.895 acc:0.410/0.430 spa:0.900 (t:1.1) \
itr700: (train/val) los:1.442/1.562 acc:0.520/0.510 spa:0.900 (t:1.1) \
itr800: (train/val) los:1.685/1.830 acc:0.410/0.330 spa:0.900 (t:1.2) \
itr900: (train/val) los:1.605/1.619 acc:0.430/0.430 spa:0.900 (t:1.1) \
itr1000: (train/val) los:1.485/1.743 acc:0.530/0.440 spa:0.900 (t:1.2) \
itr1100: (train/val) los:1.421/1.332 acc:0.510/0.550 spa:0.900 (t:1.4) \
itr1200: (train/val) los:1.461/1.687 acc:0.490/0.450 spa:0.900 (t:1.3) \
itr1300: (train/val) los:1.428/1.447 acc:0.570/0.540 spa:0.900 (t:1.3) \
itr1400: (train/val) los:1.256/1.643 acc:0.510/0.450 spa:0.900 (t:1.3) \
itr1500: (train/val) los:1.493/1.628 acc:0.520/0.460 spa:0.900 (t:1.3) \
itr1600: (train/val) los:1.444/1.534 acc:0.500/0.490 spa:0.900 (t:1.2) \
itr1700: (train/val) los:1.448/1.669 acc:0.480/0.400 spa:0.900 (t:1.1) \
itr1800: (train/val) los:1.483/1.548 acc:0.510/0.510 spa:0.900 (t:1.1) \
itr1900: (train/val) los:1.545/1.653 acc:0.490/0.450 spa:0.900 (t:1.1) \
itr2000: (train/val) los:1.463/1.724 acc:0.470/0.430 spa:0.900 (t:1.2) \
itr2100: (train/val) los:1.412/1.706 acc:0.520/0.410 spa:0.900 (t:1.2) \
itr2200: (train/val) los:1.450/1.538 acc:0.490/0.530 spa:0.900 (t:1.1) \
itr2300: (train/val) los:1.499/1.331 acc:0.470/0.530 spa:0.900 (t:1.1) \
itr2400: (train/val) los:1.260/1.646 acc:0.570/0.540 spa:0.900 (t:1.2) \
itr2500: (train/val) los:1.344/1.597 acc:0.520/0.420 spa:0.900 (t:1.3) \
itr2600: (train/val) los:1.440/1.622 acc:0.530/0.460 spa:0.900 (t:1.2) \
itr2700: (train/val) los:1.340/1.617 acc:0.570/0.470 spa:0.900 (t:1.2) \
itr2800: (train/val) los:1.283/1.746 acc:0.590/0.390 spa:0.900 (t:1.2) \
itr2900: (train/val) los:1.472/1.358 acc:0.560/0.520 spa:0.900 (t:1.2) \
itr3000: (train/val) los:1.483/1.579 acc:0.500/0.430 spa:0.900 (t:1.2) \
itr3100: (train/val) los:1.299/1.644 acc:0.590/0.440 spa:0.900 (t:1.2) \
itr3200: (train/val) los:1.452/1.665 acc:0.520/0.490 spa:0.900 (t:1.2) \
itr3300: (train/val) los:1.115/1.520 acc:0.590/0.540 spa:0.900 (t:1.1) \
itr3400: (train/val) los:1.388/1.438 acc:0.580/0.510 spa:0.900 (t:1.1) \
itr3500: (train/val) los:1.332/1.561 acc:0.580/0.430 spa:0.900 (t:1.1) \
itr3600: (train/val) los:1.178/1.639 acc:0.610/0.430 spa:0.900 (t:1.1) \
itr3700: (train/val) los:1.151/1.514 acc:0.640/0.490 spa:0.900 (t:1.1) \
itr3800: (train/val) los:1.490/1.378 acc:0.480/0.520 spa:0.900 (t:1.1) \
itr3900: (train/val) los:1.227/1.541 acc:0.550/0.490 spa:0.900 (t:1.1) \
itr4000: (train/val) los:1.290/1.516 acc:0.550/0.510 spa:0.900 (t:1.1) \
itr4100: (train/val) los:1.624/1.367 acc:0.440/0.570 spa:0.900 (t:1.2) \
itr4200: (train/val) los:1.548/1.442 acc:0.500/0.510 spa:0.900 (t:1.1) \
itr4300: (train/val) los:1.314/1.508 acc:0.510/0.540 spa:0.900 (t:1.1) \
itr4400: (train/val) los:1.334/1.678 acc:0.490/0.460 spa:0.900 (t:1.1) \
itr4500: (train/val) los:1.165/1.703 acc:0.650/0.410 spa:0.900 (t:1.1) \
itr4600: (train/val) los:1.316/1.313 acc:0.610/0.610 spa:0.900 (t:1.1) \
itr4700: (train/val) los:1.153/1.612 acc:0.620/0.490 spa:0.900 (t:1.1) \
itr4800: (train/val) los:1.102/1.385 acc:0.680/0.530 spa:0.900 (t:1.1) \
itr4900: (train/val) los:1.310/1.493 acc:0.610/0.510 spa:0.900 (t:1.1) \
itr5000: (train/val) los:1.205/1.195 acc:0.630/0.620 spa:0.900 (t:1.1) \
itr5100: (train/val) los:1.261/1.454 acc:0.560/0.570 spa:0.900 (t:1.2) \
itr5200: (train/val) los:1.299/1.563 acc:0.610/0.450 spa:0.900 (t:1.1) \
itr5300: (train/val) los:1.234/1.906 acc:0.560/0.480 spa:0.900 (t:1.1) \
itr5400: (train/val) los:1.197/1.421 acc:0.600/0.560 spa:0.900 (t:1.1) \
itr5500: (train/val) los:1.260/1.418 acc:0.620/0.520 spa:0.900 (t:1.1) \
itr5600: (train/val) los:1.188/1.367 acc:0.590/0.570 spa:0.900 (t:1.1) \
itr5700: (train/val) los:1.208/1.458 acc:0.590/0.530 spa:0.900 (t:1.1) \
itr5800: (train/val) los:1.160/1.478 acc:0.630/0.500 spa:0.900 (t:1.1) \
itr5900: (train/val) los:1.060/1.767 acc:0.690/0.470 spa:0.900 (t:1.1) \
itr6000: (train/val) los:1.123/1.578 acc:0.680/0.550 spa:0.900 (t:1.1) \
itr6100: (train/val) los:1.071/1.436 acc:0.610/0.550 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.213/1.428 acc:0.600/0.560 spa:0.900 (t:1.1) \
itr6300: (train/val) los:1.288/1.432 acc:0.510/0.590 spa:0.900 (t:1.1) \
itr6400: (train/val) los:1.178/1.506 acc:0.570/0.520 spa:0.900 (t:1.1) \
itr6500: (train/val) los:1.284/1.496 acc:0.560/0.500 spa:0.900 (t:1.1) \
itr6600: (train/val) los:1.187/1.577 acc:0.610/0.460 spa:0.900 (t:1.1) \
itr6700: (train/val) los:1.185/1.534 acc:0.620/0.540 spa:0.900 (t:1.1) \
itr6800: (train/val) los:1.210/1.405 acc:0.630/0.550 spa:0.900 (t:1.1) \
itr6900: (train/val) los:1.139/1.500 acc:0.650/0.540 spa:0.900 (t:1.1) \
itr7000: (train/val) los:1.309/1.409 acc:0.540/0.580 spa:0.900 (t:1.1) \
itr7100: (train/val) los:1.254/1.544 acc:0.570/0.570 spa:0.900 (t:1.2) \
itr7200: (train/val) los:1.041/1.612 acc:0.720/0.520 spa:0.900 (t:1.1) \
itr7300: (train/val) los:1.117/1.927 acc:0.670/0.410 spa:0.900 (t:1.1) \
itr7400: (train/val) los:1.210/1.519 acc:0.680/0.580 spa:0.900 (t:1.1) \
itr7500: (train/val) los:1.212/1.717 acc:0.610/0.420 spa:0.900 (t:1.1) \
itr7600: (train/val) los:1.112/1.568 acc:0.600/0.550 spa:0.900 (t:1.1) \
itr7700: (train/val) los:1.038/1.746 acc:0.670/0.400 spa:0.900 (t:1.1) \
itr7800: (train/val) los:1.076/1.622 acc:0.640/0.430 spa:0.900 (t:1.1) \
itr7900: (train/val) los:1.091/1.661 acc:0.670/0.470 spa:0.900 (t:1.1) \
itr8000: (train/val) los:1.207/1.729 acc:0.600/0.440 spa:0.900 (t:1.1) \
itr8100: (train/val) los:1.059/1.467 acc:0.670/0.460 spa:0.900 (t:1.2) \
itr8200: (train/val) los:1.175/1.695 acc:0.620/0.450 spa:0.900 (t:1.1) \
itr8300: (train/val) los:1.273/1.463 acc:0.570/0.530 spa:0.900 (t:1.1) \
itr8400: (train/val) los:1.184/1.361 acc:0.610/0.590 spa:0.900 (t:1.1) \
itr8500: (train/val) los:1.114/1.658 acc:0.640/0.450 spa:0.900 (t:1.1) \
itr8600: (train/val) los:1.236/1.272 acc:0.610/0.590 spa:0.900 (t:1.1) \
itr8700: (train/val) los:1.101/1.679 acc:0.660/0.550 spa:0.900 (t:1.1) \
itr8800: (train/val) los:1.085/1.493 acc:0.650/0.520 spa:0.900 (t:1.1) \
itr8900: (train/val) los:1.127/1.746 acc:0.640/0.440 spa:0.900 (t:1.1) \
itr9000: (train/val) los:1.146/1.595 acc:0.610/0.470 spa:0.900 (t:1.1) \
itr9100: (train/val) los:1.076/1.512 acc:0.590/0.540 spa:0.900 (t:1.2) \
itr9200: (train/val) los:1.157/1.437 acc:0.660/0.560 spa:0.900 (t:1.1) \
itr9300: (train/val) los:1.173/1.626 acc:0.620/0.460 spa:0.900 (t:1.1) \
itr9400: (train/val) los:1.150/1.602 acc:0.550/0.470 spa:0.900 (t:1.1) \
itr9500: (train/val) los:1.128/1.641 acc:0.630/0.520 spa:0.900 (t:1.1) \
itr9600: (train/val) los:1.166/1.679 acc:0.680/0.480 spa:0.900 (t:1.1) \
itr9700: (train/val) los:1.143/1.630 acc:0.640/0.530 spa:0.900 (t:1.1) \
itr9800: (train/val) los:1.181/1.850 acc:0.570/0.430 spa:0.900 (t:1.1) \
itr9900: (train/val) los:1.217/1.713 acc:0.620/0.440 spa:0.900 (t:1.1) \
itr10000: (train/val) los:1.294/1.597 acc:0.610/0.550 spa:0.900 (t:1.1)',
'itr100: (train/val) los:2.018/1.816 acc:0.300/0.350 spa:0.900 (t:1.2) \
itr200: (train/val) los:1.752/1.951 acc:0.440/0.370 spa:0.900 (t:1.1) \
itr300: (train/val) los:1.682/1.679 acc:0.380/0.400 spa:0.900 (t:1.1) \
itr400: (train/val) los:1.772/1.784 acc:0.330/0.360 spa:0.900 (t:1.1) \
itr500: (train/val) los:1.590/1.751 acc:0.430/0.420 spa:0.900 (t:1.1) \
itr600: (train/val) los:1.733/1.856 acc:0.470/0.420 spa:0.900 (t:1.1) \
itr700: (train/val) los:1.438/1.564 acc:0.490/0.500 spa:0.900 (t:1.1) \
itr800: (train/val) los:1.714/1.822 acc:0.360/0.360 spa:0.900 (t:1.1) \
itr900: (train/val) los:1.570/1.621 acc:0.410/0.410 spa:0.900 (t:1.1) \
itr1000: (train/val) los:1.611/1.816 acc:0.490/0.400 spa:0.900 (t:1.1) \
itr1100: (train/val) los:1.407/1.358 acc:0.520/0.540 spa:0.900 (t:1.2) \
itr1200: (train/val) los:1.501/1.682 acc:0.470/0.470 spa:0.900 (t:1.1) \
itr1300: (train/val) los:1.436/1.500 acc:0.560/0.520 spa:0.900 (t:1.1) \
itr1400: (train/val) los:1.328/1.694 acc:0.530/0.460 spa:0.900 (t:1.1) \
itr1500: (train/val) los:1.526/1.654 acc:0.510/0.380 spa:0.900 (t:1.1) \
itr1600: (train/val) los:1.480/1.562 acc:0.540/0.470 spa:0.900 (t:1.1) \
itr1700: (train/val) los:1.484/1.732 acc:0.470/0.380 spa:0.900 (t:1.1) \
itr1800: (train/val) los:1.560/1.657 acc:0.480/0.470 spa:0.900 (t:1.1) \
itr1900: (train/val) los:1.541/1.737 acc:0.480/0.390 spa:0.900 (t:1.1) \
itr2000: (train/val) los:1.518/1.644 acc:0.520/0.480 spa:0.900 (t:1.1) \
itr2100: (train/val) los:1.523/1.734 acc:0.490/0.420 spa:0.900 (t:1.2) \
itr2200: (train/val) los:1.517/1.622 acc:0.430/0.460 spa:0.900 (t:1.1) \
itr2300: (train/val) los:1.512/1.348 acc:0.500/0.570 spa:0.900 (t:1.1) \
itr2400: (train/val) los:1.342/1.537 acc:0.590/0.510 spa:0.900 (t:1.1) \
itr2500: (train/val) los:1.466/1.561 acc:0.540/0.450 spa:0.900 (t:1.1) \
itr2600: (train/val) los:1.553/1.626 acc:0.400/0.440 spa:0.900 (t:1.1) \
itr2700: (train/val) los:1.416/1.517 acc:0.480/0.520 spa:0.900 (t:1.1) \
itr2800: (train/val) los:1.198/1.656 acc:0.620/0.380 spa:0.900 (t:1.1) \
itr2900: (train/val) los:1.532/1.457 acc:0.540/0.490 spa:0.900 (t:1.1) \
itr3000: (train/val) los:1.543/1.580 acc:0.500/0.540 spa:0.900 (t:1.1) \
itr3100: (train/val) los:1.286/1.631 acc:0.590/0.440 spa:0.900 (t:1.2) \
itr3200: (train/val) los:1.496/1.570 acc:0.500/0.540 spa:0.900 (t:1.1) \
itr3300: (train/val) los:1.119/1.572 acc:0.620/0.450 spa:0.900 (t:1.1) \
itr3400: (train/val) los:1.508/1.394 acc:0.410/0.530 spa:0.900 (t:1.1) \
itr3500: (train/val) los:1.337/1.472 acc:0.600/0.480 spa:0.900 (t:1.1) \
itr3600: (train/val) los:1.174/1.728 acc:0.610/0.410 spa:0.900 (t:1.1) \
itr3700: (train/val) los:1.197/1.657 acc:0.610/0.420 spa:0.900 (t:1.1) \
itr3800: (train/val) los:1.539/1.441 acc:0.460/0.510 spa:0.900 (t:1.1) \
itr3900: (train/val) los:1.299/1.483 acc:0.520/0.500 spa:0.900 (t:1.1) \
itr4000: (train/val) los:1.283/1.501 acc:0.550/0.500 spa:0.900 (t:1.1) \
itr4100: (train/val) los:1.740/1.345 acc:0.470/0.610 spa:0.900 (t:1.2) \
itr4200: (train/val) los:1.643/1.528 acc:0.470/0.500 spa:0.900 (t:1.1) \
itr4300: (train/val) los:1.481/1.515 acc:0.460/0.490 spa:0.900 (t:1.1) \
itr4400: (train/val) los:1.389/1.597 acc:0.530/0.480 spa:0.900 (t:1.1) \
itr4500: (train/val) los:1.251/1.814 acc:0.550/0.430 spa:0.900 (t:1.1) \
itr4600: (train/val) los:1.477/1.453 acc:0.520/0.490 spa:0.900 (t:1.1) \
itr4700: (train/val) los:1.203/1.650 acc:0.610/0.540 spa:0.900 (t:1.1) \
itr4800: (train/val) los:1.172/1.476 acc:0.550/0.480 spa:0.900 (t:1.1) \
itr4900: (train/val) los:1.284/1.419 acc:0.570/0.530 spa:0.900 (t:1.1) \
itr5000: (train/val) los:1.255/1.277 acc:0.540/0.650 spa:0.900 (t:1.1) \
itr5100: (train/val) los:1.171/1.417 acc:0.590/0.570 spa:0.900 (t:1.2) \
itr5200: (train/val) los:1.349/1.544 acc:0.570/0.450 spa:0.900 (t:1.1) \
itr5300: (train/val) los:1.301/1.795 acc:0.470/0.510 spa:0.900 (t:1.1) \
itr5400: (train/val) los:1.296/1.402 acc:0.550/0.530 spa:0.900 (t:1.2) \
itr5500: (train/val) los:1.272/1.296 acc:0.600/0.500 spa:0.900 (t:1.1) \
itr5600: (train/val) los:1.234/1.453 acc:0.550/0.540 spa:0.900 (t:1.1) \
itr5700: (train/val) los:1.307/1.535 acc:0.540/0.490 spa:0.900 (t:1.1) \
itr5800: (train/val) los:1.185/1.456 acc:0.580/0.530 spa:0.900 (t:1.1) \
itr5900: (train/val) los:1.096/1.650 acc:0.670/0.510 spa:0.900 (t:1.1) \
itr6000: (train/val) los:1.201/1.565 acc:0.620/0.510 spa:0.900 (t:1.1) \
itr6100: (train/val) los:1.232/1.564 acc:0.560/0.520 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.374/1.434 acc:0.550/0.520 spa:0.900 (t:1.1) \
itr6300: (train/val) los:1.368/1.510 acc:0.500/0.520 spa:0.900 (t:1.1) \
itr6400: (train/val) los:1.164/1.577 acc:0.610/0.450 spa:0.900 (t:1.1) \
itr6500: (train/val) los:1.257/1.591 acc:0.570/0.470 spa:0.900 (t:1.1) \
itr6600: (train/val) los:1.407/1.653 acc:0.520/0.500 spa:0.900 (t:1.1) \
itr6700: (train/val) los:1.317/1.625 acc:0.580/0.450 spa:0.900 (t:1.1) \
itr6800: (train/val) los:1.246/1.470 acc:0.570/0.530 spa:0.900 (t:1.1) \
itr6900: (train/val) los:1.124/1.531 acc:0.560/0.550 spa:0.900 (t:1.1) \
itr7000: (train/val) los:1.321/1.458 acc:0.490/0.570 spa:0.900 (t:1.1) \
itr7100: (train/val) los:1.271/1.555 acc:0.600/0.540 spa:0.900 (t:1.2) \
itr7200: (train/val) los:1.072/1.634 acc:0.600/0.480 spa:0.900 (t:1.2) \
itr7300: (train/val) los:1.263/1.524 acc:0.510/0.460 spa:0.900 (t:1.1) \
itr7400: (train/val) los:1.273/1.627 acc:0.620/0.600 spa:0.900 (t:1.2) \
itr7500: (train/val) los:1.278/1.752 acc:0.560/0.460 spa:0.900 (t:1.1) \
itr7600: (train/val) los:1.049/1.473 acc:0.670/0.540 spa:0.900 (t:1.1) \
itr7700: (train/val) los:1.265/1.652 acc:0.560/0.450 spa:0.900 (t:1.1) \
itr7800: (train/val) los:1.104/1.487 acc:0.650/0.460 spa:0.900 (t:1.1) \
itr7900: (train/val) los:1.307/1.593 acc:0.570/0.480 spa:0.900 (t:1.2) \
itr8000: (train/val) los:1.269/1.551 acc:0.580/0.470 spa:0.900 (t:1.2) \
itr8100: (train/val) los:1.009/1.584 acc:0.680/0.460 spa:0.900 (t:1.2) \
itr8200: (train/val) los:1.182/1.694 acc:0.590/0.510 spa:0.900 (t:1.2) \
itr8300: (train/val) los:1.349/1.475 acc:0.530/0.610 spa:0.900 (t:1.3) \
itr8400: (train/val) los:1.126/1.278 acc:0.670/0.570 spa:0.900 (t:1.3) \
itr8500: (train/val) los:1.213/1.689 acc:0.570/0.430 spa:0.900 (t:1.1) \
itr8600: (train/val) los:1.188/1.493 acc:0.640/0.500 spa:0.900 (t:1.1) \
itr8700: (train/val) los:1.128/1.657 acc:0.700/0.500 spa:0.900 (t:1.1) \
itr8800: (train/val) los:1.149/1.448 acc:0.580/0.570 spa:0.900 (t:1.1) \
itr8900: (train/val) los:1.161/1.650 acc:0.600/0.480 spa:0.900 (t:1.1) \
itr9000: (train/val) los:1.361/1.621 acc:0.590/0.510 spa:0.900 (t:1.1) \
itr9100: (train/val) los:1.133/1.617 acc:0.640/0.480 spa:0.900 (t:1.2) \
itr9200: (train/val) los:1.100/1.428 acc:0.590/0.530 spa:0.900 (t:1.1) \
itr9300: (train/val) los:1.192/1.468 acc:0.660/0.470 spa:0.900 (t:1.1) \
itr9400: (train/val) los:1.293/1.547 acc:0.540/0.460 spa:0.900 (t:1.1) \
itr9500: (train/val) los:1.107/1.454 acc:0.590/0.550 spa:0.900 (t:1.1) \
itr9600: (train/val) los:1.104/1.655 acc:0.660/0.470 spa:0.900 (t:1.2) \
itr9700: (train/val) los:1.233/1.593 acc:0.640/0.540 spa:0.900 (t:1.1) \
itr9800: (train/val) los:1.105/1.966 acc:0.650/0.470 spa:0.900 (t:1.2) \
itr9900: (train/val) los:1.198/1.580 acc:0.550/0.480 spa:0.900 (t:1.1) \
itr10000: (train/val) los:1.239/1.564 acc:0.590/0.500 spa:0.900 (t:1.1)']

# %%
accs_tr_rnd_mask = []
accs_ts_rnd_mask = []
for mask in train_snip_mask + train_random_mask:
    tmp_tr = []
    tmp_ts = []
    for e in mask.split():
        if e[:3] == 'acc':
            tmp_tr.append(float(e[4:9]))
            tmp_ts.append(float(e[10:15]))
    accs_tr_rnd_mask.append(tmp_tr)
    accs_ts_rnd_mask.append(tmp_ts)
print(accs_tr_rnd_mask)
# Out:
# [[0.32, 0.45, 0.4, 0.38, 0.48, 0.37, 0.58, 0.44, 0.42, 0.48, 0.53, 0.47, 0.51, 0.56, 0.52, 0.55, 0.5, 0.49, 0.47, 0.53, 0.5, 0.54, 0.52, 0.58, 0.49, 0.51, 0.54, 0.55, 0.54, 0.53, 0.59, 0.52, 0.59, 0.5, 0.58, 0.63, 0.59, 0.52, 0.56, 0.57, 0.45, 0.5, 0.48, 0.45, 0.58, 0.59, 0.55, 0.66, 0.53, 0.62, 0.59, 0.56, 0.57, 0.62, 0.62, 0.58, 0.58, 0.65, 0.69, 0.61, 0.6, 0.57, 0.53, 0.58, 0.69, 0.54, 0.61, 0.68, 0.63, 0.6, 0.62, 0.7, 0.61, 0.64, 0.64, 0.68, 0.68, 0.68, 0.6, 0.63, 0.72, 0.65, 0.6, 0.6, 0.63, 0.67, 0.71, 0.66, 0.62, 0.59, 0.67, 0.65, 0.7, 0.62, 0.63, 0.6, 0.65, 0.67, 0.58, 0.62], [0.38, 0.42, 0.31, 0.4, 0.48, 0.41, 0.52, 0.41, 0.43, 0.53, 0.51, 0.49, 0.57, 0.51, 0.52, 0.5, 0.48, 0.51, 0.49, 0.47, 0.52, 0.49, 0.47, 0.57, 0.52, 0.53, 0.57, 0.59, 0.56, 0.5, 0.59, 0.52, 0.59, 0.58, 0.58, 0.61, 0.64, 0.48, 0.55, 0.55, 0.44, 0.5, 0.51, 0.49, 0.65, 0.61, 0.62, 0.68, 0.61, 0.63, 0.56, 0.61, 0.56, 0.6, 0.62, 0.59, 0.59, 0.63, 0.69, 0.68, 0.61, 0.6, 0.51, 0.57, 0.56, 0.61, 0.62, 0.63, 0.65,
# ...

# %%
plt.figure(figsize=(12,10))
line = ['-']*3 + ['--']*3
for idx, mask in enumerate(accs_tr_rnd_mask):
    plt.plot([i*100 for i in range(1, len(mask) + 1)], mask, line[idx], alpha=0.5)
plt.title('lenet300, CIFAR, sparsity 0.9, signed constant')
# Out:
# Text(0.5, 1.0, 'lenet300, CIFAR, sparsity 0.9, signed constant')

# %%
plt.figure(figsize=(12,10))
line = ['-']*3 + ['--']*3
for idx, mask in enumerate(accs_ts_rnd_mask):
    plt.plot([i*100 for i in range(1, len(mask) + 1)], mask, line[idx], alpha=0.5)
plt.title('lenet300, CIFAR, sparsity 0.9, signed constant')
# Out:
# Text(0.5, 1.0, 'lenet300, CIFAR, sparsity 0.9, signed constant')

# %%
#0.9
train_snip_mask = ['itr100: (train/val) los:2.062/1.869 acc:0.250/0.290 spa:0.900 (t:1.2) \
itr200: (train/val) los:1.742/1.911 acc:0.440/0.350 spa:0.900 (t:1.1) \
itr300: (train/val) los:1.671/1.661 acc:0.340/0.400 spa:0.900 (t:1.1) \
itr400: (train/val) los:1.728/1.707 acc:0.390/0.380 spa:0.900 (t:1.1) \
itr500: (train/val) los:1.589/1.741 acc:0.440/0.470 spa:0.900 (t:1.2) \
itr600: (train/val) los:1.667/1.869 acc:0.450/0.370 spa:0.900 (t:1.1) \
itr700: (train/val) los:1.470/1.536 acc:0.530/0.550 spa:0.900 (t:1.1) \
itr800: (train/val) los:1.627/1.716 acc:0.400/0.390 spa:0.900 (t:1.1) \
itr900: (train/val) los:1.565/1.596 acc:0.450/0.420 spa:0.900 (t:1.1) \
itr1000: (train/val) los:1.535/1.695 acc:0.460/0.430 spa:0.900 (t:1.1) \
itr1100: (train/val) los:1.364/1.342 acc:0.510/0.540 spa:0.900 (t:1.2) \
itr1200: (train/val) los:1.368/1.645 acc:0.510/0.460 spa:0.900 (t:1.2) \
itr1300: (train/val) los:1.406/1.498 acc:0.590/0.510 spa:0.900 (t:1.1) \
itr1400: (train/val) los:1.220/1.567 acc:0.530/0.450 spa:0.900 (t:1.1) \
itr1500: (train/val) los:1.497/1.544 acc:0.480/0.470 spa:0.900 (t:1.1) \
itr1600: (train/val) los:1.410/1.534 acc:0.520/0.440 spa:0.900 (t:1.1) \
itr1700: (train/val) los:1.405/1.760 acc:0.480/0.380 spa:0.900 (t:1.1) \
itr1800: (train/val) los:1.408/1.461 acc:0.550/0.530 spa:0.900 (t:1.2) \
itr1900: (train/val) los:1.468/1.699 acc:0.490/0.400 spa:0.900 (t:1.3) \
itr2000: (train/val) los:1.517/1.699 acc:0.480/0.430 spa:0.900 (t:1.2) \
itr2100: (train/val) los:1.449/1.708 acc:0.520/0.410 spa:0.900 (t:1.4) \
itr2200: (train/val) los:1.469/1.471 acc:0.540/0.490 spa:0.900 (t:1.3) \
itr2300: (train/val) los:1.398/1.364 acc:0.550/0.510 spa:0.900 (t:1.2) \
itr2400: (train/val) los:1.261/1.450 acc:0.510/0.530 spa:0.900 (t:1.1) \
itr2500: (train/val) los:1.396/1.555 acc:0.490/0.480 spa:0.900 (t:1.2) \
itr2600: (train/val) los:1.472/1.605 acc:0.510/0.440 spa:0.900 (t:1.3) \
itr2700: (train/val) los:1.308/1.470 acc:0.560/0.520 spa:0.900 (t:1.2) \
itr2800: (train/val) los:1.131/1.550 acc:0.590/0.430 spa:0.900 (t:1.2) \
itr2900: (train/val) los:1.485/1.468 acc:0.550/0.450 spa:0.900 (t:1.2) \
itr3000: (train/val) los:1.521/1.479 acc:0.500/0.520 spa:0.900 (t:1.1) \
itr3100: (train/val) los:1.318/1.590 acc:0.530/0.420 spa:0.900 (t:1.2) \
itr3200: (train/val) los:1.398/1.529 acc:0.520/0.520 spa:0.900 (t:1.1) \
itr3300: (train/val) los:1.048/1.485 acc:0.650/0.510 spa:0.900 (t:1.2) \
itr3400: (train/val) los:1.374/1.322 acc:0.500/0.530 spa:0.900 (t:1.2) \
itr3500: (train/val) los:1.317/1.493 acc:0.560/0.510 spa:0.900 (t:1.1) \
itr3600: (train/val) los:1.063/1.470 acc:0.660/0.460 spa:0.900 (t:1.2) \
itr3700: (train/val) los:1.126/1.552 acc:0.700/0.470 spa:0.900 (t:1.2) \
itr3800: (train/val) los:1.462/1.310 acc:0.540/0.520 spa:0.900 (t:1.1) \
itr3900: (train/val) los:1.205/1.473 acc:0.560/0.490 spa:0.900 (t:1.1) \
itr4000: (train/val) los:1.137/1.482 acc:0.620/0.480 spa:0.900 (t:1.1) \
itr4100: (train/val) los:1.506/1.314 acc:0.480/0.550 spa:0.900 (t:1.2) \
itr4200: (train/val) los:1.495/1.390 acc:0.490/0.500 spa:0.900 (t:1.1) \
itr4300: (train/val) los:1.402/1.512 acc:0.460/0.510 spa:0.900 (t:1.2) \
itr4400: (train/val) los:1.311/1.601 acc:0.530/0.560 spa:0.900 (t:1.4) \
itr4500: (train/val) los:1.126/1.654 acc:0.630/0.480 spa:0.900 (t:1.4) \
itr4600: (train/val) los:1.367/1.435 acc:0.590/0.480 spa:0.900 (t:1.2) \
itr4700: (train/val) los:1.107/1.576 acc:0.630/0.560 spa:0.900 (t:1.2) \
itr4800: (train/val) los:1.087/1.482 acc:0.660/0.540 spa:0.900 (t:1.2) \
itr4900: (train/val) los:1.278/1.463 acc:0.640/0.510 spa:0.900 (t:1.4) \
itr5000: (train/val) los:1.214/1.257 acc:0.580/0.590 spa:0.900 (t:1.2) \
itr5100: (train/val) los:1.161/1.339 acc:0.640/0.610 spa:0.900 (t:1.3) \
itr5200: (train/val) los:1.187/1.487 acc:0.620/0.490 spa:0.900 (t:1.1) \
itr5300: (train/val) los:1.118/1.724 acc:0.600/0.530 spa:0.900 (t:1.2) \
itr5400: (train/val) los:1.113/1.378 acc:0.630/0.530 spa:0.900 (t:1.2) \
itr5500: (train/val) los:1.199/1.387 acc:0.610/0.460 spa:0.900 (t:1.2) \
itr5600: (train/val) los:1.073/1.405 acc:0.640/0.540 spa:0.900 (t:1.2) \
itr5700: (train/val) los:1.284/1.613 acc:0.610/0.460 spa:0.900 (t:1.2) \
itr5800: (train/val) los:1.025/1.433 acc:0.650/0.540 spa:0.900 (t:1.2) \
itr5900: (train/val) los:0.979/1.702 acc:0.700/0.460 spa:0.900 (t:1.2) \
itr6000: (train/val) los:1.043/1.621 acc:0.690/0.540 spa:0.900 (t:1.2) \
itr6100: (train/val) los:1.021/1.470 acc:0.680/0.510 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.248/1.334 acc:0.560/0.590 spa:0.900 (t:1.2) \
itr6300: (train/val) los:1.295/1.478 acc:0.530/0.500 spa:0.900 (t:1.1) \
itr6400: (train/val) los:1.101/1.526 acc:0.630/0.460 spa:0.900 (t:1.1) \
itr6500: (train/val) los:1.163/1.548 acc:0.600/0.520 spa:0.900 (t:1.2) \
itr6600: (train/val) los:1.117/1.595 acc:0.620/0.520 spa:0.900 (t:1.2) \
itr6700: (train/val) los:1.104/1.536 acc:0.620/0.510 spa:0.900 (t:1.4) \
itr6800: (train/val) los:1.045/1.442 acc:0.670/0.590 spa:0.900 (t:1.3) \
itr6900: (train/val) los:0.979/1.344 acc:0.690/0.590 spa:0.900 (t:1.3) \
itr7000: (train/val) los:1.043/1.513 acc:0.640/0.550 spa:0.900 (t:1.4) \
itr7100: (train/val) los:1.161/1.562 acc:0.610/0.530 spa:0.900 (t:1.4) \
itr7200: (train/val) los:0.946/1.557 acc:0.740/0.510 spa:0.900 (t:1.3) \
itr7300: (train/val) los:1.044/1.667 acc:0.670/0.410 spa:0.900 (t:1.2) \
itr7400: (train/val) los:1.158/1.414 acc:0.640/0.670 spa:0.900 (t:1.1) \
itr7500: (train/val) los:1.148/1.612 acc:0.610/0.510 spa:0.900 (t:1.2) \
itr7600: (train/val) los:0.992/1.629 acc:0.670/0.540 spa:0.900 (t:1.2) \
itr7700: (train/val) los:1.070/1.686 acc:0.660/0.440 spa:0.900 (t:1.2) \
itr7800: (train/val) los:1.113/1.613 acc:0.640/0.460 spa:0.900 (t:1.3) \
itr7900: (train/val) los:1.179/1.595 acc:0.700/0.500 spa:0.900 (t:1.4) \
itr8000: (train/val) los:0.996/1.671 acc:0.700/0.490 spa:0.900 (t:1.3) \
itr8100: (train/val) los:0.873/1.554 acc:0.760/0.470 spa:0.900 (t:1.4) \
itr8200: (train/val) los:1.045/1.697 acc:0.630/0.460 spa:0.900 (t:1.5) \
itr8300: (train/val) los:1.191/1.431 acc:0.550/0.640 spa:0.900 (t:1.2) \
itr8400: (train/val) los:1.144/1.388 acc:0.580/0.580 spa:0.900 (t:1.1) \
itr8500: (train/val) los:1.105/1.595 acc:0.650/0.490 spa:0.900 (t:1.1) \
itr8600: (train/val) los:1.101/1.300 acc:0.660/0.570 spa:0.900 (t:1.1) \
itr8700: (train/val) los:1.054/1.675 acc:0.730/0.560 spa:0.900 (t:1.2) \
itr8800: (train/val) los:0.951/1.495 acc:0.680/0.570 spa:0.900 (t:1.2) \
itr8900: (train/val) los:1.015/1.672 acc:0.650/0.510 spa:0.900 (t:1.2) \
itr9000: (train/val) los:1.106/1.545 acc:0.650/0.490 spa:0.900 (t:1.2) \
itr9100: (train/val) los:0.923/1.701 acc:0.720/0.550 spa:0.900 (t:1.2) \
itr9200: (train/val) los:1.075/1.429 acc:0.670/0.560 spa:0.900 (t:1.1) \
itr9300: (train/val) los:1.182/1.562 acc:0.680/0.530 spa:0.900 (t:1.2) \
itr9400: (train/val) los:1.016/1.648 acc:0.620/0.460 spa:0.900 (t:1.1) \
itr9500: (train/val) los:1.051/1.585 acc:0.720/0.590 spa:0.900 (t:1.1) \
itr9600: (train/val) los:0.987/1.581 acc:0.670/0.510 spa:0.900 (t:1.1) \
itr9700: (train/val) los:1.119/1.710 acc:0.670/0.530 spa:0.900 (t:1.1) \
itr9800: (train/val) los:1.113/1.809 acc:0.690/0.480 spa:0.900 (t:1.1) \
itr9900: (train/val) los:1.202/1.622 acc:0.630/0.460 spa:0.900 (t:1.1) \
itr10000: (train/val) los:1.109/1.699 acc:0.640/0.540 spa:0.900 (t:1.1)',
'itr100: (train/val) los:2.033/1.822 acc:0.330/0.340 spa:0.900 (t:1.3) \
itr200: (train/val) los:1.762/1.903 acc:0.420/0.380 spa:0.900 (t:1.1) \
itr300: (train/val) los:1.629/1.682 acc:0.340/0.350 spa:0.900 (t:1.1) \
itr400: (train/val) los:1.757/1.776 acc:0.410/0.300 spa:0.900 (t:1.1) \
itr500: (train/val) los:1.585/1.746 acc:0.480/0.420 spa:0.900 (t:1.2) \
itr600: (train/val) los:1.735/1.734 acc:0.430/0.420 spa:0.900 (t:1.4) \
itr700: (train/val) los:1.445/1.512 acc:0.560/0.500 spa:0.900 (t:1.1) \
itr800: (train/val) los:1.644/1.750 acc:0.410/0.310 spa:0.900 (t:1.1) \
itr900: (train/val) los:1.565/1.595 acc:0.490/0.460 spa:0.900 (t:1.2) \
itr1000: (train/val) los:1.599/1.696 acc:0.470/0.380 spa:0.900 (t:1.2) \
itr1100: (train/val) los:1.379/1.391 acc:0.510/0.540 spa:0.900 (t:1.3) \
itr1200: (train/val) los:1.423/1.618 acc:0.490/0.440 spa:0.900 (t:1.4) \
itr1300: (train/val) los:1.427/1.425 acc:0.550/0.550 spa:0.900 (t:1.3) \
itr1400: (train/val) los:1.253/1.590 acc:0.540/0.440 spa:0.900 (t:1.3) \
itr1500: (train/val) los:1.503/1.610 acc:0.480/0.450 spa:0.900 (t:1.2) \
itr1600: (train/val) los:1.427/1.474 acc:0.580/0.510 spa:0.900 (t:1.2) \
itr1700: (train/val) los:1.484/1.698 acc:0.420/0.370 spa:0.900 (t:1.2) \
itr1800: (train/val) los:1.464/1.576 acc:0.530/0.490 spa:0.900 (t:1.2) \
itr1900: (train/val) los:1.512/1.718 acc:0.470/0.430 spa:0.900 (t:1.3) \
itr2000: (train/val) los:1.484/1.611 acc:0.500/0.490 spa:0.900 (t:1.3) \
itr2100: (train/val) los:1.425/1.682 acc:0.530/0.440 spa:0.900 (t:1.3) \
itr2200: (train/val) los:1.534/1.520 acc:0.420/0.440 spa:0.900 (t:1.2) \
itr2300: (train/val) los:1.433/1.294 acc:0.480/0.550 spa:0.900 (t:1.3) \
itr2400: (train/val) los:1.318/1.496 acc:0.580/0.550 spa:0.900 (t:1.2) \
itr2500: (train/val) los:1.430/1.511 acc:0.460/0.480 spa:0.900 (t:1.2) \
itr2600: (train/val) los:1.456/1.569 acc:0.470/0.430 spa:0.900 (t:1.2) \
itr2700: (train/val) los:1.396/1.526 acc:0.500/0.460 spa:0.900 (t:1.1) \
itr2800: (train/val) los:1.276/1.665 acc:0.550/0.390 spa:0.900 (t:1.1) \
itr2900: (train/val) los:1.429/1.458 acc:0.520/0.450 spa:0.900 (t:1.3) \
itr3000: (train/val) los:1.533/1.480 acc:0.520/0.530 spa:0.900 (t:1.3) \
itr3100: (train/val) los:1.305/1.571 acc:0.530/0.460 spa:0.900 (t:1.3) \
itr3200: (train/val) los:1.437/1.594 acc:0.550/0.480 spa:0.900 (t:1.2) \
itr3300: (train/val) los:1.104/1.588 acc:0.580/0.480 spa:0.900 (t:1.2) \
itr3400: (train/val) los:1.373/1.358 acc:0.530/0.540 spa:0.900 (t:1.2) \
itr3500: (train/val) los:1.330/1.563 acc:0.510/0.470 spa:0.900 (t:1.2) \
itr3600: (train/val) los:1.226/1.632 acc:0.610/0.440 spa:0.900 (t:1.2) \
itr3700: (train/val) los:1.216/1.597 acc:0.570/0.440 spa:0.900 (t:1.2) \
itr3800: (train/val) los:1.531/1.404 acc:0.470/0.560 spa:0.900 (t:1.2) \
itr3900: (train/val) los:1.322/1.444 acc:0.550/0.540 spa:0.900 (t:1.1) \
itr4000: (train/val) los:1.216/1.471 acc:0.620/0.510 spa:0.900 (t:1.2) \
itr4100: (train/val) los:1.556/1.316 acc:0.480/0.560 spa:0.900 (t:1.2) \
itr4200: (train/val) los:1.552/1.426 acc:0.490/0.490 spa:0.900 (t:1.2) \
itr4300: (train/val) los:1.375/1.504 acc:0.510/0.480 spa:0.900 (t:1.1) \
itr4400: (train/val) los:1.480/1.753 acc:0.500/0.440 spa:0.900 (t:1.2) \
itr4500: (train/val) los:1.180/1.719 acc:0.600/0.400 spa:0.900 (t:1.2) \
itr4600: (train/val) los:1.440/1.381 acc:0.500/0.500 spa:0.900 (t:1.1) \
itr4700: (train/val) los:1.196/1.642 acc:0.600/0.490 spa:0.900 (t:1.3) \
itr4800: (train/val) los:1.103/1.455 acc:0.630/0.530 spa:0.900 (t:1.2) \
itr4900: (train/val) los:1.246/1.452 acc:0.560/0.480 spa:0.900 (t:1.2) \
itr5000: (train/val) los:1.166/1.335 acc:0.550/0.560 spa:0.900 (t:1.2) \
itr5100: (train/val) los:1.111/1.350 acc:0.660/0.580 spa:0.900 (t:1.3) \
itr5200: (train/val) los:1.304/1.514 acc:0.620/0.480 spa:0.900 (t:1.2) \
itr5300: (train/val) los:1.216/1.611 acc:0.550/0.520 spa:0.900 (t:1.4) \
itr5400: (train/val) los:1.187/1.364 acc:0.610/0.570 spa:0.900 (t:1.3) \
itr5500: (train/val) los:1.291/1.302 acc:0.620/0.540 spa:0.900 (t:1.2) \
itr5600: (train/val) los:1.171/1.363 acc:0.610/0.580 spa:0.900 (t:1.2) \
itr5700: (train/val) los:1.381/1.617 acc:0.580/0.450 spa:0.900 (t:1.2) \
itr5800: (train/val) los:1.109/1.397 acc:0.610/0.580 spa:0.900 (t:1.1) \
itr5900: (train/val) los:1.083/1.719 acc:0.670/0.400 spa:0.900 (t:1.1) \
itr6000: (train/val) los:1.219/1.506 acc:0.610/0.520 spa:0.900 (t:1.1) \
itr6100: (train/val) los:1.051/1.517 acc:0.600/0.550 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.303/1.387 acc:0.520/0.560 spa:0.900 (t:1.1) \
itr6300: (train/val) los:1.307/1.490 acc:0.530/0.550 spa:0.900 (t:1.1) \
itr6400: (train/val) los:1.249/1.439 acc:0.520/0.550 spa:0.900 (t:1.1) \
itr6500: (train/val) los:1.158/1.509 acc:0.640/0.490 spa:0.900 (t:1.2) \
itr6600: (train/val) los:1.209/1.514 acc:0.550/0.490 spa:0.900 (t:1.2) \
itr6700: (train/val) los:1.285/1.572 acc:0.570/0.500 spa:0.900 (t:1.2) \
itr6800: (train/val) los:1.269/1.345 acc:0.630/0.580 spa:0.900 (t:1.1) \
itr6900: (train/val) los:1.023/1.436 acc:0.620/0.560 spa:0.900 (t:1.2) \
itr7000: (train/val) los:1.152/1.406 acc:0.590/0.530 spa:0.900 (t:1.2) \
itr7100: (train/val) los:1.198/1.564 acc:0.670/0.540 spa:0.900 (t:1.2) \
itr7200: (train/val) los:0.980/1.690 acc:0.660/0.450 spa:0.900 (t:1.1) \
itr7300: (train/val) los:1.146/1.666 acc:0.640/0.450 spa:0.900 (t:1.1) \
itr7400: (train/val) los:1.095/1.533 acc:0.700/0.560 spa:0.900 (t:1.1) \
itr7500: (train/val) los:1.161/1.641 acc:0.640/0.440 spa:0.900 (t:1.1) \
itr7600: (train/val) los:1.047/1.584 acc:0.640/0.500 spa:0.900 (t:1.1) \
itr7700: (train/val) los:1.086/1.575 acc:0.670/0.480 spa:0.900 (t:1.1) \
itr7800: (train/val) los:1.181/1.724 acc:0.620/0.420 spa:0.900 (t:1.1) \
itr7900: (train/val) los:1.198/1.639 acc:0.640/0.520 spa:0.900 (t:1.1) \
itr8000: (train/val) los:1.108/1.571 acc:0.640/0.520 spa:0.900 (t:1.1) \
itr8100: (train/val) los:0.857/1.492 acc:0.700/0.490 spa:0.900 (t:1.2) \
itr8200: (train/val) los:1.181/1.726 acc:0.590/0.470 spa:0.900 (t:1.1) \
itr8300: (train/val) los:1.288/1.454 acc:0.640/0.530 spa:0.900 (t:1.1) \
itr8400: (train/val) los:1.229/1.383 acc:0.620/0.540 spa:0.900 (t:1.1) \
itr8500: (train/val) los:1.111/1.552 acc:0.640/0.490 spa:0.900 (t:1.1) \
itr8600: (train/val) los:1.132/1.248 acc:0.660/0.610 spa:0.900 (t:1.1) \
itr8700: (train/val) los:1.170/1.561 acc:0.630/0.540 spa:0.900 (t:1.2) \
itr8800: (train/val) los:1.091/1.394 acc:0.660/0.540 spa:0.900 (t:1.1) \
itr8900: (train/val) los:1.129/1.730 acc:0.620/0.420 spa:0.900 (t:1.2) \
itr9000: (train/val) los:1.144/1.713 acc:0.640/0.490 spa:0.900 (t:1.2) \
itr9100: (train/val) los:1.191/1.614 acc:0.610/0.500 spa:0.900 (t:1.2) \
itr9200: (train/val) los:1.063/1.592 acc:0.640/0.490 spa:0.900 (t:1.1) \
itr9300: (train/val) los:1.207/1.560 acc:0.620/0.480 spa:0.900 (t:1.3) \
itr9400: (train/val) los:1.161/1.688 acc:0.560/0.440 spa:0.900 (t:1.1) \
itr9500: (train/val) los:1.085/1.493 acc:0.620/0.580 spa:0.900 (t:1.2) \
itr9600: (train/val) los:1.087/1.622 acc:0.630/0.490 spa:0.900 (t:1.3) \
itr9700: (train/val) los:1.105/1.663 acc:0.610/0.510 spa:0.900 (t:1.2) \
itr9800: (train/val) los:1.082/1.841 acc:0.720/0.520 spa:0.900 (t:1.2) \
itr9900: (train/val) los:1.141/1.610 acc:0.630/0.470 spa:0.900 (t:1.1) \
itr10000: (train/val) los:1.205/1.886 acc:0.620/0.460 spa:0.900 (t:1.1)']

# %%
#0.9
train_random_mask = ['itr100: (train/val) los:2.231/2.232 acc:0.200/0.240 spa:0.900 (t:1.3) \
itr200: (train/val) los:2.117/2.184 acc:0.290/0.230 spa:0.900 (t:1.2) \
itr300: (train/val) los:1.864/1.950 acc:0.350/0.310 spa:0.900 (t:1.2) \
itr400: (train/val) los:1.815/1.974 acc:0.390/0.220 spa:0.900 (t:1.2) \
itr500: (train/val) los:1.865/1.983 acc:0.360/0.310 spa:0.900 (t:1.2) \
itr600: (train/val) los:1.675/1.844 acc:0.460/0.340 spa:0.900 (t:1.2) \
itr700: (train/val) los:1.747/1.676 acc:0.420/0.440 spa:0.900 (t:1.2) \
itr800: (train/val) los:1.732/1.825 acc:0.420/0.320 spa:0.900 (t:1.2) \
itr900: (train/val) los:1.760/1.682 acc:0.340/0.400 spa:0.900 (t:1.2) \
itr1000: (train/val) los:1.563/1.771 acc:0.480/0.420 spa:0.900 (t:1.2) \
itr1100: (train/val) los:1.551/1.402 acc:0.490/0.480 spa:0.900 (t:1.2) \
itr1200: (train/val) los:1.393/1.707 acc:0.520/0.440 spa:0.900 (t:1.2) \
itr1300: (train/val) los:1.517/1.545 acc:0.460/0.440 spa:0.900 (t:1.1) \
itr1400: (train/val) los:1.381/1.590 acc:0.490/0.420 spa:0.900 (t:1.1) \
itr1500: (train/val) los:1.400/1.637 acc:0.540/0.380 spa:0.900 (t:1.1) \
itr1600: (train/val) los:1.543/1.537 acc:0.510/0.490 spa:0.900 (t:1.1) \
itr1700: (train/val) los:1.459/1.645 acc:0.470/0.430 spa:0.900 (t:1.1) \
itr1800: (train/val) los:1.419/1.525 acc:0.540/0.520 spa:0.900 (t:1.2) \
itr1900: (train/val) los:1.478/1.659 acc:0.500/0.410 spa:0.900 (t:1.2) \
itr2000: (train/val) los:1.437/1.676 acc:0.460/0.470 spa:0.900 (t:1.2) \
itr2100: (train/val) los:1.610/1.707 acc:0.480/0.440 spa:0.900 (t:1.2) \
itr2200: (train/val) los:1.481/1.501 acc:0.490/0.450 spa:0.900 (t:1.2) \
itr2300: (train/val) los:1.303/1.457 acc:0.550/0.470 spa:0.900 (t:1.2) \
itr2400: (train/val) los:1.390/1.561 acc:0.550/0.520 spa:0.900 (t:1.1) \
itr2500: (train/val) los:1.464/1.712 acc:0.530/0.390 spa:0.900 (t:1.1) \
itr2600: (train/val) los:1.446/1.557 acc:0.520/0.380 spa:0.900 (t:1.2) \
itr2700: (train/val) los:1.511/1.429 acc:0.510/0.510 spa:0.900 (t:1.2) \
itr2800: (train/val) los:1.434/1.599 acc:0.470/0.400 spa:0.900 (t:1.2) \
itr2900: (train/val) los:1.482/1.444 acc:0.500/0.450 spa:0.900 (t:1.2) \
itr3000: (train/val) los:1.403/1.654 acc:0.480/0.430 spa:0.900 (t:1.4) \
itr3100: (train/val) los:1.349/1.588 acc:0.490/0.430 spa:0.900 (t:1.3) \
itr3200: (train/val) los:1.399/1.636 acc:0.560/0.410 spa:0.900 (t:1.6) \
itr3300: (train/val) los:1.496/1.600 acc:0.470/0.460 spa:0.900 (t:1.3) \
itr3400: (train/val) los:1.456/1.439 acc:0.460/0.480 spa:0.900 (t:1.2) \
itr3500: (train/val) los:1.370/1.497 acc:0.530/0.500 spa:0.900 (t:1.2) \
itr3600: (train/val) los:1.334/1.647 acc:0.590/0.430 spa:0.900 (t:1.1) \
itr3700: (train/val) los:1.222/1.604 acc:0.610/0.450 spa:0.900 (t:1.2) \
itr3800: (train/val) los:1.261/1.428 acc:0.590/0.500 spa:0.900 (t:1.2) \
itr3900: (train/val) los:1.135/1.442 acc:0.580/0.500 spa:0.900 (t:1.2) \
itr4000: (train/val) los:1.245/1.614 acc:0.630/0.490 spa:0.900 (t:1.2) \
itr4100: (train/val) los:1.294/1.405 acc:0.580/0.540 spa:0.900 (t:1.2) \
itr4200: (train/val) los:1.322/1.475 acc:0.520/0.570 spa:0.900 (t:1.2) \
itr4300: (train/val) los:1.258/1.457 acc:0.590/0.470 spa:0.900 (t:1.2) \
itr4400: (train/val) los:1.239/1.703 acc:0.600/0.440 spa:0.900 (t:1.2) \
itr4500: (train/val) los:1.310/1.722 acc:0.530/0.410 spa:0.900 (t:1.2) \
itr4600: (train/val) los:1.242/1.400 acc:0.580/0.500 spa:0.900 (t:1.2) \
itr4700: (train/val) los:1.516/1.550 acc:0.490/0.470 spa:0.900 (t:1.2) \
itr4800: (train/val) los:1.234/1.452 acc:0.560/0.510 spa:0.900 (t:1.2) \
itr4900: (train/val) los:1.349/1.592 acc:0.590/0.480 spa:0.900 (t:1.2) \
itr5000: (train/val) los:1.168/1.270 acc:0.550/0.640 spa:0.900 (t:1.2) \
itr5100: (train/val) los:1.301/1.360 acc:0.570/0.570 spa:0.900 (t:1.2) \
itr5200: (train/val) los:1.449/1.582 acc:0.510/0.420 spa:0.900 (t:1.2) \
itr5300: (train/val) los:1.578/1.816 acc:0.540/0.470 spa:0.900 (t:1.2) \
itr5400: (train/val) los:1.370/1.558 acc:0.580/0.470 spa:0.900 (t:1.2) \
itr5500: (train/val) los:1.364/1.367 acc:0.560/0.520 spa:0.900 (t:1.2) \
itr5600: (train/val) los:1.311/1.518 acc:0.580/0.460 spa:0.900 (t:1.2) \
itr5700: (train/val) los:1.260/1.684 acc:0.620/0.480 spa:0.900 (t:1.2) \
itr5800: (train/val) los:1.084/1.581 acc:0.680/0.490 spa:0.900 (t:1.1) \
itr5900: (train/val) los:1.216/1.719 acc:0.570/0.470 spa:0.900 (t:1.2) \
itr6000: (train/val) los:1.246/1.620 acc:0.580/0.560 spa:0.900 (t:1.2) \
itr6100: (train/val) los:1.055/1.583 acc:0.670/0.520 spa:0.900 (t:1.2) \
itr6200: (train/val) los:1.457/1.527 acc:0.530/0.470 spa:0.900 (t:1.2) \
itr6300: (train/val) los:1.348/1.463 acc:0.570/0.550 spa:0.900 (t:1.2) \
itr6400: (train/val) los:1.282/1.582 acc:0.570/0.460 spa:0.900 (t:1.2) \
itr6500: (train/val) los:1.131/1.593 acc:0.640/0.470 spa:0.900 (t:1.2) \
itr6600: (train/val) los:1.202/1.734 acc:0.620/0.430 spa:0.900 (t:1.1) \
itr6700: (train/val) los:1.242/1.693 acc:0.620/0.400 spa:0.900 (t:1.2) \
itr6800: (train/val) los:1.091/1.608 acc:0.650/0.510 spa:0.900 (t:1.2) \
itr6900: (train/val) los:1.245/1.470 acc:0.630/0.560 spa:0.900 (t:1.2) \
itr7000: (train/val) los:1.127/1.487 acc:0.650/0.560 spa:0.900 (t:1.2) \
itr7100: (train/val) los:1.456/1.652 acc:0.540/0.550 spa:0.900 (t:1.2) \
itr7200: (train/val) los:1.142/1.603 acc:0.670/0.500 spa:0.900 (t:1.2) \
itr7300: (train/val) los:1.203/1.730 acc:0.580/0.430 spa:0.900 (t:1.2) \
itr7400: (train/val) los:1.126/1.423 acc:0.690/0.550 spa:0.900 (t:1.2) \
itr7500: (train/val) los:1.051/1.821 acc:0.670/0.420 spa:0.900 (t:1.2) \
itr7600: (train/val) los:1.270/1.518 acc:0.650/0.580 spa:0.900 (t:1.2) \
itr7700: (train/val) los:1.067/1.642 acc:0.640/0.480 spa:0.900 (t:1.2) \
itr7800: (train/val) los:1.046/1.803 acc:0.670/0.410 spa:0.900 (t:1.1) \
itr7900: (train/val) los:1.071/1.483 acc:0.620/0.520 spa:0.900 (t:1.2) \
itr8000: (train/val) los:1.322/1.824 acc:0.540/0.460 spa:0.900 (t:1.2) \
itr8100: (train/val) los:1.103/1.661 acc:0.640/0.410 spa:0.900 (t:1.2) \
itr8200: (train/val) los:1.173/1.613 acc:0.530/0.420 spa:0.900 (t:1.2) \
itr8300: (train/val) los:1.129/1.479 acc:0.650/0.510 spa:0.900 (t:1.2) \
itr8400: (train/val) los:1.085/1.571 acc:0.660/0.500 spa:0.900 (t:1.2) \
itr8500: (train/val) los:1.053/1.683 acc:0.640/0.470 spa:0.900 (t:1.2) \
itr8600: (train/val) los:0.940/1.283 acc:0.680/0.610 spa:0.900 (t:1.2) \
itr8700: (train/val) los:1.128/1.828 acc:0.660/0.510 spa:0.900 (t:1.2) \
itr8800: (train/val) los:1.175/1.567 acc:0.660/0.500 spa:0.900 (t:1.1) \
itr8900: (train/val) los:1.157/1.896 acc:0.640/0.370 spa:0.900 (t:1.2) \
itr9000: (train/val) los:1.075/1.820 acc:0.630/0.490 spa:0.900 (t:1.1) \
itr9100: (train/val) los:1.197/1.704 acc:0.590/0.490 spa:0.900 (t:1.2) \
itr9200: (train/val) los:1.171/1.556 acc:0.610/0.520 spa:0.900 (t:1.2) \
itr9300: (train/val) los:1.310/1.564 acc:0.540/0.430 spa:0.900 (t:1.2) \
itr9400: (train/val) los:1.199/1.757 acc:0.600/0.440 spa:0.900 (t:1.2) \
itr9500: (train/val) los:1.186/1.760 acc:0.570/0.550 spa:0.900 (t:1.2) \
itr9600: (train/val) los:1.144/1.714 acc:0.610/0.500 spa:0.900 (t:1.2) \
itr9700: (train/val) los:1.108/1.820 acc:0.640/0.460 spa:0.900 (t:1.1) \
itr9800: (train/val) los:1.084/1.643 acc:0.720/0.500 spa:0.900 (t:1.2) \
itr9900: (train/val) los:1.020/1.489 acc:0.700/0.520 spa:0.900 (t:1.2) \
itr10000: (train/val) los:0.955/1.759 acc:0.670/0.460 spa:0.900 (t:1.2)',
'itr100: (train/val) los:2.222/2.241 acc:0.190/0.220 spa:0.900 (t:1.3) \
itr200: (train/val) los:2.107/2.196 acc:0.290/0.200 spa:0.900 (t:1.2) \
itr300: (train/val) los:1.880/2.022 acc:0.360/0.260 spa:0.900 (t:1.2) \
itr400: (train/val) los:1.829/1.988 acc:0.390/0.260 spa:0.900 (t:1.2) \
itr500: (train/val) los:1.867/2.005 acc:0.360/0.290 spa:0.900 (t:1.2) \
itr600: (train/val) los:1.724/1.898 acc:0.400/0.370 spa:0.900 (t:1.2) \
itr700: (train/val) los:1.761/1.630 acc:0.430/0.460 spa:0.900 (t:1.2) \
itr800: (train/val) los:1.682/1.803 acc:0.470/0.320 spa:0.900 (t:1.2) \
itr900: (train/val) los:1.706/1.713 acc:0.410/0.430 spa:0.900 (t:1.2) \
itr1000: (train/val) los:1.627/1.707 acc:0.480/0.420 spa:0.900 (t:1.3) \
itr1100: (train/val) los:1.535/1.381 acc:0.470/0.520 spa:0.900 (t:1.2) \
itr1200: (train/val) los:1.425/1.699 acc:0.500/0.400 spa:0.900 (t:1.2) \
itr1300: (train/val) los:1.509/1.510 acc:0.480/0.500 spa:0.900 (t:1.2) \
itr1400: (train/val) los:1.442/1.605 acc:0.480/0.400 spa:0.900 (t:1.2) \
itr1500: (train/val) los:1.369/1.640 acc:0.540/0.380 spa:0.900 (t:1.2) \
itr1600: (train/val) los:1.551/1.553 acc:0.520/0.470 spa:0.900 (t:1.2) \
itr1700: (train/val) los:1.493/1.674 acc:0.500/0.380 spa:0.900 (t:1.2) \
itr1800: (train/val) los:1.406/1.522 acc:0.550/0.510 spa:0.900 (t:1.2) \
itr1900: (train/val) los:1.459/1.674 acc:0.510/0.430 spa:0.900 (t:1.2) \
itr2000: (train/val) los:1.429/1.726 acc:0.410/0.470 spa:0.900 (t:1.2) \
itr2100: (train/val) los:1.582/1.641 acc:0.470/0.460 spa:0.900 (t:1.2) \
itr2200: (train/val) los:1.496/1.477 acc:0.470/0.470 spa:0.900 (t:1.2) \
itr2300: (train/val) los:1.247/1.380 acc:0.630/0.530 spa:0.900 (t:1.2) \
itr2400: (train/val) los:1.358/1.603 acc:0.560/0.530 spa:0.900 (t:1.2) \
itr2500: (train/val) los:1.379/1.611 acc:0.520/0.440 spa:0.900 (t:1.2) \
itr2600: (train/val) los:1.457/1.713 acc:0.520/0.420 spa:0.900 (t:1.2) \
itr2700: (train/val) los:1.482/1.445 acc:0.430/0.530 spa:0.900 (t:1.2) \
itr2800: (train/val) los:1.443/1.642 acc:0.470/0.390 spa:0.900 (t:1.2) \
itr2900: (train/val) los:1.422/1.474 acc:0.520/0.420 spa:0.900 (t:1.2) \
itr3000: (train/val) los:1.367/1.625 acc:0.520/0.510 spa:0.900 (t:1.2) \
itr3100: (train/val) los:1.281/1.575 acc:0.560/0.400 spa:0.900 (t:1.2) \
itr3200: (train/val) los:1.420/1.637 acc:0.470/0.470 spa:0.900 (t:1.2) \
itr3300: (train/val) los:1.435/1.644 acc:0.480/0.410 spa:0.900 (t:1.2) \
itr3400: (train/val) los:1.496/1.330 acc:0.490/0.550 spa:0.900 (t:1.2) \
itr3500: (train/val) los:1.438/1.498 acc:0.420/0.490 spa:0.900 (t:1.2) \
itr3600: (train/val) los:1.345/1.596 acc:0.530/0.440 spa:0.900 (t:1.2) \
itr3700: (train/val) los:1.257/1.686 acc:0.620/0.420 spa:0.900 (t:1.2) \
itr3800: (train/val) los:1.144/1.402 acc:0.600/0.510 spa:0.900 (t:1.2) \
itr3900: (train/val) los:1.146/1.497 acc:0.660/0.470 spa:0.900 (t:1.2) \
itr4000: (train/val) los:1.290/1.561 acc:0.580/0.500 spa:0.900 (t:1.2) \
itr4100: (train/val) los:1.287/1.483 acc:0.580/0.490 spa:0.900 (t:1.2) \
itr4200: (train/val) los:1.362/1.414 acc:0.480/0.490 spa:0.900 (t:1.2) \
itr4300: (train/val) los:1.303/1.634 acc:0.560/0.460 spa:0.900 (t:1.2) \
itr4400: (train/val) los:1.219/1.749 acc:0.550/0.430 spa:0.900 (t:1.2) \
itr4500: (train/val) los:1.321/1.748 acc:0.570/0.410 spa:0.900 (t:1.2) \
itr4600: (train/val) los:1.326/1.421 acc:0.540/0.510 spa:0.900 (t:1.2) \
itr4700: (train/val) los:1.520/1.552 acc:0.510/0.510 spa:0.900 (t:1.2) \
itr4800: (train/val) los:1.262/1.536 acc:0.620/0.480 spa:0.900 (t:1.2) \
itr4900: (train/val) los:1.459/1.550 acc:0.460/0.480 spa:0.900 (t:1.2) \
itr5000: (train/val) los:1.174/1.375 acc:0.610/0.520 spa:0.900 (t:1.2) \
itr5100: (train/val) los:1.262/1.529 acc:0.590/0.490 spa:0.900 (t:1.2) \
itr5200: (train/val) los:1.338/1.559 acc:0.540/0.440 spa:0.900 (t:1.2) \
itr5300: (train/val) los:1.609/1.832 acc:0.580/0.420 spa:0.900 (t:1.2) \
itr5400: (train/val) los:1.327/1.502 acc:0.570/0.480 spa:0.900 (t:1.3) \
itr5500: (train/val) los:1.344/1.462 acc:0.640/0.460 spa:0.900 (t:1.2) \
itr5600: (train/val) los:1.277/1.462 acc:0.570/0.500 spa:0.900 (t:1.3) \
itr5700: (train/val) los:1.235/1.767 acc:0.600/0.400 spa:0.900 (t:1.2) \
itr5800: (train/val) los:1.081/1.493 acc:0.650/0.490 spa:0.900 (t:1.2) \
itr5900: (train/val) los:1.290/1.624 acc:0.520/0.520 spa:0.900 (t:1.2) \
itr6000: (train/val) los:1.210/1.651 acc:0.580/0.490 spa:0.900 (t:1.3) \
itr6100: (train/val) los:1.138/1.515 acc:0.590/0.530 spa:0.900 (t:1.3) \
itr6200: (train/val) los:1.442/1.389 acc:0.560/0.560 spa:0.900 (t:1.3) \
itr6300: (train/val) los:1.428/1.541 acc:0.520/0.460 spa:0.900 (t:1.3) \
itr6400: (train/val) los:1.275/1.641 acc:0.520/0.480 spa:0.900 (t:1.2) \
itr6500: (train/val) los:1.119/1.644 acc:0.650/0.460 spa:0.900 (t:1.2) \
itr6600: (train/val) los:1.220/1.631 acc:0.590/0.460 spa:0.900 (t:1.2) \
itr6700: (train/val) los:1.287/1.545 acc:0.570/0.490 spa:0.900 (t:1.2) \
itr6800: (train/val) los:1.082/1.390 acc:0.660/0.540 spa:0.900 (t:1.2) \
itr6900: (train/val) los:1.194/1.477 acc:0.680/0.570 spa:0.900 (t:1.2) \
itr7000: (train/val) los:1.089/1.465 acc:0.700/0.570 spa:0.900 (t:1.2) \
itr7100: (train/val) los:1.326/1.619 acc:0.550/0.520 spa:0.900 (t:1.2) \
itr7200: (train/val) los:1.162/1.557 acc:0.640/0.510 spa:0.900 (t:1.2) \
itr7300: (train/val) los:1.226/1.719 acc:0.560/0.420 spa:0.900 (t:1.2) \
itr7400: (train/val) los:1.035/1.489 acc:0.680/0.610 spa:0.900 (t:1.2) \
itr7500: (train/val) los:1.010/1.756 acc:0.670/0.470 spa:0.900 (t:1.2) \
itr7600: (train/val) los:1.225/1.576 acc:0.630/0.530 spa:0.900 (t:1.2) \
itr7700: (train/val) los:1.096/1.785 acc:0.620/0.440 spa:0.900 (t:1.2) \
itr7800: (train/val) los:1.079/1.687 acc:0.640/0.460 spa:0.900 (t:1.2) \
itr7900: (train/val) los:0.979/1.490 acc:0.680/0.520 spa:0.900 (t:1.2) \
itr8000: (train/val) los:1.121/1.844 acc:0.680/0.500 spa:0.900 (t:1.2) \
itr8100: (train/val) los:1.172/1.609 acc:0.660/0.420 spa:0.900 (t:1.2) \
itr8200: (train/val) los:1.226/1.951 acc:0.590/0.380 spa:0.900 (t:1.2) \
itr8300: (train/val) los:1.177/1.429 acc:0.620/0.570 spa:0.900 (t:1.2) \
itr8400: (train/val) los:1.078/1.432 acc:0.670/0.530 spa:0.900 (t:1.2) \
itr8500: (train/val) los:1.141/1.846 acc:0.660/0.430 spa:0.900 (t:1.2) \
itr8600: (train/val) los:1.004/1.344 acc:0.680/0.570 spa:0.900 (t:1.2) \
itr8700: (train/val) los:1.147/1.894 acc:0.640/0.440 spa:0.900 (t:1.2) \
itr8800: (train/val) los:1.097/1.705 acc:0.650/0.460 spa:0.900 (t:1.2) \
itr8900: (train/val) los:1.210/1.835 acc:0.570/0.430 spa:0.900 (t:1.2) \
itr9000: (train/val) los:1.114/1.770 acc:0.640/0.460 spa:0.900 (t:1.2) \
itr9100: (train/val) los:1.234/1.608 acc:0.610/0.500 spa:0.900 (t:1.2) \
itr9200: (train/val) los:1.230/1.669 acc:0.580/0.440 spa:0.900 (t:1.2) \
itr9300: (train/val) los:1.413/1.679 acc:0.530/0.470 spa:0.900 (t:1.2) \
itr9400: (train/val) los:1.195/1.619 acc:0.590/0.510 spa:0.900 (t:1.2) \
itr9500: (train/val) los:1.153/1.700 acc:0.620/0.550 spa:0.900 (t:1.2) \
itr9600: (train/val) los:1.262/1.687 acc:0.560/0.490 spa:0.900 (t:1.2) \
itr9700: (train/val) los:1.127/1.646 acc:0.590/0.520 spa:0.900 (t:1.2) \
itr9800: (train/val) los:0.979/1.714 acc:0.660/0.490 spa:0.900 (t:1.2) \
itr9900: (train/val) los:1.146/1.617 acc:0.610/0.490 spa:0.900 (t:1.2) \
itr10000: (train/val) los:0.992/1.729 acc:0.670/0.420 spa:0.900 (t:1.2)']

# %%
accs_tr_rnd_mask = []
accs_ts_rnd_mask = []
for mask in train_snip_mask + train_random_mask:
    tmp_tr = []
    tmp_ts = []
    for e in mask.split():
        if e[:3] == 'acc':
            tmp_tr.append(float(e[4:9]))
            tmp_ts.append(float(e[10:15]))
    accs_tr_rnd_mask.append(tmp_tr)
    accs_ts_rnd_mask.append(tmp_ts)
print(accs_tr_rnd_mask)
# Out:
# [[0.25, 0.44, 0.34, 0.39, 0.44, 0.45, 0.53, 0.4, 0.45, 0.46, 0.51, 0.51, 0.59, 0.53, 0.48, 0.52, 0.48, 0.55, 0.49, 0.48, 0.52, 0.54, 0.55, 0.51, 0.49, 0.51, 0.56, 0.59, 0.55, 0.5, 0.53, 0.52, 0.65, 0.5, 0.56, 0.66, 0.7, 0.54, 0.56, 0.62, 0.48, 0.49, 0.46, 0.53, 0.63, 0.59, 0.63, 0.66, 0.64, 0.58, 0.64, 0.62, 0.6, 0.63, 0.61, 0.64, 0.61, 0.65, 0.7, 0.69, 0.68, 0.56, 0.53, 0.63, 0.6, 0.62, 0.62, 0.67, 0.69, 0.64, 0.61, 0.74, 0.67, 0.64, 0.61, 0.67, 0.66, 0.64, 0.7, 0.7, 0.76, 0.63, 0.55, 0.58, 0.65, 0.66, 0.73, 0.68, 0.65, 0.65, 0.72, 0.67, 0.68, 0.62, 0.72, 0.67, 0.67, 0.69, 0.63, 0.64], [0.33, 0.42, 0.34, 0.41, 0.48, 0.43, 0.56, 0.41, 0.49, 0.47, 0.51, 0.49, 0.55, 0.54, 0.48, 0.58, 0.42, 0.53, 0.47, 0.5, 0.53, 0.42, 0.48, 0.58, 0.46, 0.47, 0.5, 0.55, 0.52, 0.52, 0.53, 0.55, 0.58, 0.53, 0.51, 0.61, 0.57, 0.47, 0.55, 0.62, 0.48, 0.49, 0.51, 0.5, 0.6, 0.5, 0.6, 0.63, 0.56, 0.55, 0.66, 0.62, 0.55, 0.61, 0.62, 0.61, 0.58, 0.61, 0.67, 0.61, 0.6, 0.52, 0.53, 0.52, 0.64, 0.55, 0.57, 0.63, 0.
# ...

# %%
plt.figure(figsize=(12,10))
line = ['-']*2 + ['--']*2
for idx, mask in enumerate(accs_tr_rnd_mask):
    plt.plot([i*100 for i in range(1, len(mask) + 1)], mask, line[idx], alpha=0.5)
plt.title('lenet300, CIFAR, sparsity 0.9, variance scaling')
# Out:
# Text(0.5, 1.0, 'lenet300, CIFAR, sparsity 0.9, variance scaling')

# %%
plt.figure(figsize=(12,10))
line = ['-']*2 + ['--']*2
for idx, mask in enumerate(accs_ts_rnd_mask):
    plt.plot([i*100 for i in range(1, len(mask) + 1)], mask, line[idx], alpha=0.5)
plt.title('lenet300, CIFAR, sparsity 0.9, variance scaling')
# Out:
# Text(0.5, 1.0, 'lenet300, CIFAR, sparsity 0.9, variance scaling')

# %%
random_mask = {}
random_mask['w1'] = np.random.choice(2, p=[0.6, 0.4], size=(32*32*3,300)).astype(np.float32)
random_mask['w2'] = np.random.choice(2, p=[0.6, 0.4], size=(300,100)).astype(np.float32)
random_mask['w3'] = np.random.choice(2, p=[0.6, 0.4], size=(100,10)).astype(np.float32)

random_mask['b1'] = np.zeros(300).astype(np.float32)
random_mask['b2'] = np.zeros(100).astype(np.float32)
random_mask['b3'] = np.zeros(10).astype(np.float32)

with open('masks_lenet300_cifar/random_60_2', 'wb') as f:
    pickle.dump(random_mask, f)

# %%
#0.6
train_snip_mask = ['itr100: (train/val) los:1.976/1.783 acc:0.360/0.400 spa:0.600 (t:1.3) \
itr200: (train/val) los:1.722/1.878 acc:0.490/0.360 spa:0.600 (t:1.1) \
itr300: (train/val) los:1.624/1.660 acc:0.380/0.420 spa:0.600 (t:1.1) \
itr400: (train/val) los:1.695/1.666 acc:0.440/0.410 spa:0.600 (t:1.2) \
itr500: (train/val) los:1.532/1.676 acc:0.440/0.480 spa:0.600 (t:1.2) \
itr600: (train/val) los:1.574/1.814 acc:0.480/0.420 spa:0.600 (t:1.2) \
itr700: (train/val) los:1.376/1.391 acc:0.590/0.530 spa:0.600 (t:1.1) \
itr800: (train/val) los:1.662/1.742 acc:0.420/0.410 spa:0.600 (t:1.2) \
itr900: (train/val) los:1.471/1.561 acc:0.500/0.460 spa:0.600 (t:1.1) \
itr1000: (train/val) los:1.481/1.590 acc:0.490/0.480 spa:0.600 (t:1.1) \
itr1100: (train/val) los:1.377/1.345 acc:0.480/0.520 spa:0.600 (t:1.2) \
itr1200: (train/val) los:1.361/1.617 acc:0.550/0.440 spa:0.600 (t:1.1) \
itr1300: (train/val) los:1.364/1.392 acc:0.560/0.580 spa:0.600 (t:1.1) \
itr1400: (train/val) los:1.139/1.546 acc:0.580/0.440 spa:0.600 (t:1.1) \
itr1500: (train/val) los:1.314/1.493 acc:0.550/0.410 spa:0.600 (t:1.1) \
itr1600: (train/val) los:1.319/1.543 acc:0.530/0.430 spa:0.600 (t:1.1) \
itr1700: (train/val) los:1.361/1.717 acc:0.540/0.390 spa:0.600 (t:1.1) \
itr1800: (train/val) los:1.366/1.587 acc:0.570/0.490 spa:0.600 (t:1.2) \
itr1900: (train/val) los:1.395/1.708 acc:0.530/0.420 spa:0.600 (t:1.2) \
itr2000: (train/val) los:1.349/1.588 acc:0.600/0.490 spa:0.600 (t:1.1) \
itr2100: (train/val) los:1.363/1.729 acc:0.590/0.430 spa:0.600 (t:1.2) \
itr2200: (train/val) los:1.350/1.518 acc:0.590/0.500 spa:0.600 (t:1.1) \
itr2300: (train/val) los:1.319/1.449 acc:0.530/0.510 spa:0.600 (t:1.1) \
itr2400: (train/val) los:1.261/1.418 acc:0.570/0.600 spa:0.600 (t:1.1) \
itr2500: (train/val) los:1.215/1.528 acc:0.610/0.470 spa:0.600 (t:1.1) \
itr2600: (train/val) los:1.317/1.631 acc:0.590/0.460 spa:0.600 (t:1.1) \
itr2700: (train/val) los:1.192/1.571 acc:0.550/0.520 spa:0.600 (t:1.1) \
itr2800: (train/val) los:1.065/1.596 acc:0.670/0.440 spa:0.600 (t:1.1) \
itr2900: (train/val) los:1.324/1.463 acc:0.560/0.510 spa:0.600 (t:1.1) \
itr3000: (train/val) los:1.428/1.524 acc:0.520/0.500 spa:0.600 (t:1.1) \
itr3100: (train/val) los:1.190/1.517 acc:0.670/0.470 spa:0.600 (t:1.2) \
itr3200: (train/val) los:1.336/1.653 acc:0.570/0.490 spa:0.600 (t:1.1) \
itr3300: (train/val) los:1.054/1.551 acc:0.600/0.530 spa:0.600 (t:1.1) \
itr3400: (train/val) los:1.377/1.393 acc:0.530/0.510 spa:0.600 (t:1.1) \
itr3500: (train/val) los:1.072/1.623 acc:0.660/0.490 spa:0.600 (t:1.1) \
itr3600: (train/val) los:1.075/1.723 acc:0.670/0.410 spa:0.600 (t:1.1) \
itr3700: (train/val) los:1.028/1.680 acc:0.630/0.430 spa:0.600 (t:1.1) \
itr3800: (train/val) los:1.349/1.450 acc:0.530/0.580 spa:0.600 (t:1.1) \
itr3900: (train/val) los:1.165/1.595 acc:0.620/0.500 spa:0.600 (t:1.1) \
itr4000: (train/val) los:1.121/1.543 acc:0.610/0.490 spa:0.600 (t:1.1) \
itr4100: (train/val) los:1.395/1.407 acc:0.520/0.530 spa:0.600 (t:1.2) \
itr4200: (train/val) los:1.368/1.527 acc:0.600/0.440 spa:0.600 (t:1.1) \
itr4300: (train/val) los:1.175/1.675 acc:0.600/0.530 spa:0.600 (t:1.1) \
itr4400: (train/val) los:1.203/1.876 acc:0.630/0.440 spa:0.600 (t:1.1) \
itr4500: (train/val) los:0.955/1.675 acc:0.690/0.450 spa:0.600 (t:1.1) \
itr4600: (train/val) los:1.235/1.547 acc:0.630/0.530 spa:0.600 (t:1.1) \
itr4700: (train/val) los:1.040/1.691 acc:0.700/0.510 spa:0.600 (t:1.1) \
itr4800: (train/val) los:0.945/1.443 acc:0.660/0.580 spa:0.600 (t:1.1) \
itr4900: (train/val) los:1.226/1.595 acc:0.620/0.500 spa:0.600 (t:1.1) \
itr5000: (train/val) los:1.032/1.395 acc:0.660/0.550 spa:0.600 (t:1.1) \
itr5100: (train/val) los:0.929/1.507 acc:0.690/0.570 spa:0.600 (t:1.2) \
itr5200: (train/val) los:1.083/1.534 acc:0.660/0.560 spa:0.600 (t:1.1) \
itr5300: (train/val) los:1.091/1.819 acc:0.600/0.470 spa:0.600 (t:1.1) \
itr5400: (train/val) los:0.926/1.454 acc:0.730/0.570 spa:0.600 (t:1.1) \
itr5500: (train/val) los:1.008/1.325 acc:0.640/0.540 spa:0.600 (t:1.1) \
itr5600: (train/val) los:0.910/1.485 acc:0.660/0.520 spa:0.600 (t:1.1) \
itr5700: (train/val) los:1.014/1.735 acc:0.720/0.470 spa:0.600 (t:1.1) \
itr5800: (train/val) los:0.999/1.565 acc:0.690/0.590 spa:0.600 (t:1.1) \
itr5900: (train/val) los:0.788/2.003 acc:0.790/0.470 spa:0.600 (t:1.1) \
itr6000: (train/val) los:0.803/1.816 acc:0.810/0.520 spa:0.600 (t:1.1) \
itr6100: (train/val) los:0.830/1.707 acc:0.750/0.530 spa:0.600 (t:1.2) \
itr6200: (train/val) los:1.049/1.553 acc:0.680/0.590 spa:0.600 (t:1.1) \
itr6300: (train/val) los:1.075/1.519 acc:0.640/0.510 spa:0.600 (t:1.1) \
itr6400: (train/val) los:1.003/1.477 acc:0.700/0.490 spa:0.600 (t:1.1) \
itr6500: (train/val) los:0.967/1.905 acc:0.710/0.350 spa:0.600 (t:1.1) \
itr6600: (train/val) los:1.010/1.667 acc:0.650/0.540 spa:0.600 (t:1.1) \
itr6700: (train/val) los:1.140/1.636 acc:0.630/0.550 spa:0.600 (t:1.1) \
itr6800: (train/val) los:0.875/1.572 acc:0.730/0.540 spa:0.600 (t:1.1) \
itr6900: (train/val) los:0.864/1.538 acc:0.750/0.560 spa:0.600 (t:1.1) \
itr7000: (train/val) los:0.979/1.521 acc:0.680/0.550 spa:0.600 (t:1.1) \
itr7100: (train/val) los:0.951/1.694 acc:0.780/0.530 spa:0.600 (t:1.2) \
itr7200: (train/val) los:0.725/1.859 acc:0.790/0.530 spa:0.600 (t:1.1) \
itr7300: (train/val) los:0.843/2.029 acc:0.710/0.410 spa:0.600 (t:1.1) \
itr7400: (train/val) los:0.936/1.684 acc:0.740/0.590 spa:0.600 (t:1.1) \
itr7500: (train/val) los:0.939/2.114 acc:0.680/0.450 spa:0.600 (t:1.1) \
itr7600: (train/val) los:0.960/1.953 acc:0.740/0.550 spa:0.600 (t:1.1) \
itr7700: (train/val) los:1.006/2.141 acc:0.710/0.470 spa:0.600 (t:1.1) \
itr7800: (train/val) los:0.883/1.674 acc:0.690/0.490 spa:0.600 (t:1.1) \
itr7900: (train/val) los:1.036/1.606 acc:0.710/0.470 spa:0.600 (t:1.1) \
itr8000: (train/val) los:1.005/1.840 acc:0.710/0.490 spa:0.600 (t:1.1) \
itr8100: (train/val) los:0.690/1.823 acc:0.820/0.430 spa:0.600 (t:1.2) \
itr8200: (train/val) los:0.862/2.055 acc:0.740/0.430 spa:0.600 (t:1.1) \
itr8300: (train/val) los:0.955/1.608 acc:0.750/0.520 spa:0.600 (t:1.1) \
itr8400: (train/val) los:0.857/1.728 acc:0.730/0.560 spa:0.600 (t:1.2) \
itr8500: (train/val) los:1.062/1.917 acc:0.640/0.390 spa:0.600 (t:1.1) \
itr8600: (train/val) los:0.906/1.754 acc:0.780/0.530 spa:0.600 (t:1.1) \
itr8700: (train/val) los:0.861/2.115 acc:0.750/0.460 spa:0.600 (t:1.2) \
itr8800: (train/val) los:0.813/1.480 acc:0.780/0.590 spa:0.600 (t:1.1) \
itr8900: (train/val) los:1.018/2.125 acc:0.690/0.420 spa:0.600 (t:1.1) \
itr9000: (train/val) los:0.854/2.098 acc:0.770/0.460 spa:0.600 (t:1.1) \
itr9100: (train/val) los:0.733/1.860 acc:0.760/0.510 spa:0.600 (t:1.2) \
itr9200: (train/val) los:1.068/1.759 acc:0.730/0.510 spa:0.600 (t:1.1) \
itr9300: (train/val) los:0.940/1.714 acc:0.710/0.490 spa:0.600 (t:1.1) \
itr9400: (train/val) los:0.966/1.930 acc:0.700/0.460 spa:0.600 (t:1.1) \
itr9500: (train/val) los:0.786/1.966 acc:0.780/0.510 spa:0.600 (t:1.1) \
itr9600: (train/val) los:0.899/1.498 acc:0.750/0.560 spa:0.600 (t:1.1) \
itr9700: (train/val) los:0.857/2.301 acc:0.760/0.470 spa:0.600 (t:1.1) \
itr9800: (train/val) los:0.846/1.934 acc:0.790/0.450 spa:0.600 (t:1.1) \
itr9900: (train/val) los:1.120/2.094 acc:0.710/0.480 spa:0.600 (t:1.1) \
itr10000: (train/val) los:0.758/2.286 acc:0.780/0.460 spa:0.600 (t:1.1)', 
'itr100: (train/val) los:1.941/1.718 acc:0.380/0.430 spa:0.600 (t:1.4) \
itr200: (train/val) los:1.684/1.892 acc:0.470/0.390 spa:0.600 (t:1.2) \
itr300: (train/val) los:1.632/1.659 acc:0.340/0.440 spa:0.600 (t:1.3) \
itr400: (train/val) los:1.639/1.639 acc:0.420/0.370 spa:0.600 (t:1.4) \
itr500: (train/val) los:1.532/1.703 acc:0.520/0.490 spa:0.600 (t:1.3) \
itr600: (train/val) los:1.643/1.812 acc:0.450/0.430 spa:0.600 (t:1.2) \
itr700: (train/val) los:1.352/1.450 acc:0.580/0.530 spa:0.600 (t:1.2) \
itr800: (train/val) los:1.626/1.725 acc:0.410/0.370 spa:0.600 (t:1.3) \
itr900: (train/val) los:1.550/1.577 acc:0.480/0.430 spa:0.600 (t:1.2) \
itr1000: (train/val) los:1.486/1.682 acc:0.530/0.420 spa:0.600 (t:1.2) \
itr1100: (train/val) los:1.367/1.371 acc:0.500/0.510 spa:0.600 (t:1.3) \
itr1200: (train/val) los:1.356/1.646 acc:0.500/0.450 spa:0.600 (t:1.3) \
itr1300: (train/val) los:1.382/1.436 acc:0.550/0.560 spa:0.600 (t:1.2) \
itr1400: (train/val) los:1.102/1.504 acc:0.610/0.480 spa:0.600 (t:1.2) \
itr1500: (train/val) los:1.423/1.559 acc:0.550/0.430 spa:0.600 (t:1.2) \
itr1600: (train/val) los:1.380/1.378 acc:0.510/0.510 spa:0.600 (t:1.1) \
itr1700: (train/val) los:1.363/1.702 acc:0.570/0.390 spa:0.600 (t:1.2) \
itr1800: (train/val) los:1.385/1.585 acc:0.520/0.490 spa:0.600 (t:1.2) \
itr1900: (train/val) los:1.357/1.621 acc:0.570/0.480 spa:0.600 (t:1.1) \
itr2000: (train/val) los:1.403/1.650 acc:0.580/0.440 spa:0.600 (t:1.2) \
itr2100: (train/val) los:1.363/1.643 acc:0.540/0.480 spa:0.600 (t:1.2) \
itr2200: (train/val) los:1.356/1.442 acc:0.490/0.470 spa:0.600 (t:1.2) \
itr2300: (train/val) los:1.327/1.319 acc:0.560/0.520 spa:0.600 (t:1.1) \
itr2400: (train/val) los:1.174/1.495 acc:0.680/0.550 spa:0.600 (t:1.1) \
itr2500: (train/val) los:1.286/1.573 acc:0.550/0.490 spa:0.600 (t:1.1) \
itr2600: (train/val) los:1.301/1.603 acc:0.560/0.450 spa:0.600 (t:1.1) \
itr2700: (train/val) los:1.163/1.506 acc:0.560/0.530 spa:0.600 (t:1.1) \
itr2800: (train/val) los:1.049/1.707 acc:0.610/0.440 spa:0.600 (t:1.1) \
itr2900: (train/val) los:1.306/1.466 acc:0.600/0.430 spa:0.600 (t:1.1) \
itr3000: (train/val) los:1.450/1.487 acc:0.470/0.490 spa:0.600 (t:1.1) \
itr3100: (train/val) los:1.188/1.514 acc:0.610/0.470 spa:0.600 (t:1.2) \
itr3200: (train/val) los:1.166/1.656 acc:0.610/0.460 spa:0.600 (t:1.1) \
itr3300: (train/val) los:1.002/1.569 acc:0.620/0.540 spa:0.600 (t:1.1) \
itr3400: (train/val) los:1.232/1.298 acc:0.550/0.560 spa:0.600 (t:1.2) \
itr3500: (train/val) los:1.171/1.727 acc:0.620/0.470 spa:0.600 (t:1.2) \
itr3600: (train/val) los:0.971/1.627 acc:0.690/0.460 spa:0.600 (t:1.1) \
itr3700: (train/val) los:0.932/1.614 acc:0.680/0.470 spa:0.600 (t:1.1) \
itr3800: (train/val) los:1.344/1.523 acc:0.510/0.560 spa:0.600 (t:1.1) \
itr3900: (train/val) los:1.071/1.655 acc:0.590/0.490 spa:0.600 (t:1.1) \
itr4000: (train/val) los:1.036/1.611 acc:0.670/0.490 spa:0.600 (t:1.1) \
itr4100: (train/val) los:1.335/1.511 acc:0.540/0.450 spa:0.600 (t:1.2) \
itr4200: (train/val) los:1.354/1.555 acc:0.570/0.510 spa:0.600 (t:1.1) \
itr4300: (train/val) los:1.204/1.725 acc:0.580/0.460 spa:0.600 (t:1.1) \
itr4400: (train/val) los:1.299/1.833 acc:0.540/0.500 spa:0.600 (t:1.1) \
itr4500: (train/val) los:0.960/1.718 acc:0.680/0.420 spa:0.600 (t:1.1) \
itr4600: (train/val) los:1.288/1.629 acc:0.590/0.510 spa:0.600 (t:1.1) \
itr4700: (train/val) los:1.052/1.771 acc:0.650/0.500 spa:0.600 (t:1.1) \
itr4800: (train/val) los:0.992/1.454 acc:0.720/0.530 spa:0.600 (t:1.1) \
itr4900: (train/val) los:1.180/1.571 acc:0.610/0.500 spa:0.600 (t:1.1) \
itr5000: (train/val) los:0.966/1.355 acc:0.720/0.560 spa:0.600 (t:1.1) \
itr5100: (train/val) los:1.091/1.608 acc:0.650/0.570 spa:0.600 (t:1.2) \
itr5200: (train/val) los:1.120/1.517 acc:0.650/0.520 spa:0.600 (t:1.1) \
itr5300: (train/val) los:1.013/1.858 acc:0.650/0.500 spa:0.600 (t:1.1) \
itr5400: (train/val) los:0.909/1.604 acc:0.690/0.540 spa:0.600 (t:1.1) \
itr5500: (train/val) los:1.000/1.341 acc:0.700/0.580 spa:0.600 (t:1.1) \
itr5600: (train/val) los:0.969/1.620 acc:0.700/0.540 spa:0.600 (t:1.1) \
itr5700: (train/val) los:1.063/1.756 acc:0.630/0.440 spa:0.600 (t:1.1) \
itr5800: (train/val) los:0.956/1.583 acc:0.720/0.490 spa:0.600 (t:1.1) \
itr5900: (train/val) los:0.816/1.907 acc:0.790/0.450 spa:0.600 (t:1.1) \
itr6000: (train/val) los:0.933/1.777 acc:0.700/0.540 spa:0.600 (t:1.1) \
itr6100: (train/val) los:0.786/1.748 acc:0.780/0.530 spa:0.600 (t:1.2) \
itr6200: (train/val) los:1.088/1.527 acc:0.670/0.590 spa:0.600 (t:1.1) \
itr6300: (train/val) los:1.059/1.641 acc:0.640/0.580 spa:0.600 (t:1.2) \
itr6400: (train/val) los:0.883/1.629 acc:0.710/0.520 spa:0.600 (t:1.2) \
itr6500: (train/val) los:1.015/1.705 acc:0.730/0.450 spa:0.600 (t:1.3) \
itr6600: (train/val) los:0.990/1.723 acc:0.660/0.520 spa:0.600 (t:1.2) \
itr6700: (train/val) los:1.119/1.814 acc:0.640/0.500 spa:0.600 (t:1.4) \
itr6800: (train/val) los:0.856/1.508 acc:0.740/0.590 spa:0.600 (t:1.3) \
itr6900: (train/val) los:0.795/1.501 acc:0.780/0.570 spa:0.600 (t:1.4) \
itr7000: (train/val) los:1.010/1.551 acc:0.640/0.580 spa:0.600 (t:1.4) \
itr7100: (train/val) los:0.943/1.900 acc:0.710/0.510 spa:0.600 (t:1.4) \
itr7200: (train/val) los:0.834/1.891 acc:0.760/0.500 spa:0.600 (t:1.2) \
itr7300: (train/val) los:0.832/1.797 acc:0.760/0.480 spa:0.600 (t:1.1) \
itr7400: (train/val) los:1.155/1.773 acc:0.670/0.600 spa:0.600 (t:1.1) \
itr7500: (train/val) los:0.952/1.898 acc:0.750/0.550 spa:0.600 (t:1.1) \
itr7600: (train/val) los:0.859/1.729 acc:0.690/0.550 spa:0.600 (t:1.2) \
itr7700: (train/val) los:0.899/1.793 acc:0.730/0.510 spa:0.600 (t:1.2) \
itr7800: (train/val) los:0.813/1.942 acc:0.760/0.460 spa:0.600 (t:1.2) \
itr7900: (train/val) los:0.898/1.883 acc:0.720/0.480 spa:0.600 (t:1.1) \
itr8000: (train/val) los:0.951/1.808 acc:0.700/0.510 spa:0.600 (t:1.1) \
itr8100: (train/val) los:0.748/1.608 acc:0.810/0.440 spa:0.600 (t:1.2) \
itr8200: (train/val) los:0.884/1.797 acc:0.720/0.490 spa:0.600 (t:1.1) \
itr8300: (train/val) los:0.987/1.729 acc:0.710/0.590 spa:0.600 (t:1.1) \
itr8400: (train/val) los:0.974/1.649 acc:0.690/0.530 spa:0.600 (t:1.1) \
itr8500: (train/val) los:0.961/1.966 acc:0.720/0.440 spa:0.600 (t:1.1) \
itr8600: (train/val) los:0.898/1.542 acc:0.750/0.530 spa:0.600 (t:1.1) \
itr8700: (train/val) los:0.813/2.089 acc:0.770/0.510 spa:0.600 (t:1.1) \
itr8800: (train/val) los:0.797/1.614 acc:0.730/0.550 spa:0.600 (t:1.1) \
itr8900: (train/val) los:0.916/1.940 acc:0.720/0.450 spa:0.600 (t:1.1) \
itr9000: (train/val) los:0.847/2.110 acc:0.800/0.480 spa:0.600 (t:1.1) \
itr9100: (train/val) los:0.716/1.966 acc:0.790/0.510 spa:0.600 (t:1.2) \
itr9200: (train/val) los:0.805/1.570 acc:0.780/0.600 spa:0.600 (t:1.1) \
itr9300: (train/val) los:0.971/1.835 acc:0.730/0.480 spa:0.600 (t:1.1) \
itr9400: (train/val) los:0.988/1.814 acc:0.610/0.480 spa:0.600 (t:1.1) \
itr9500: (train/val) los:0.760/1.945 acc:0.810/0.520 spa:0.600 (t:1.1) \
itr9600: (train/val) los:0.811/1.992 acc:0.770/0.410 spa:0.600 (t:1.1) \
itr9700: (train/val) los:0.894/2.094 acc:0.720/0.470 spa:0.600 (t:1.1) \
itr9800: (train/val) los:0.904/1.931 acc:0.740/0.530 spa:0.600 (t:1.1) \
itr9900: (train/val) los:1.094/1.916 acc:0.710/0.460 spa:0.600 (t:1.2) \
itr10000: (train/val) los:1.068/2.374 acc:0.700/0.480 spa:0.600 (t:1.2)']

# %%
#0.6
train_random_mask = ['itr100: (train/val) los:1.814/1.797 acc:0.410/0.380 spa:0.600 (t:1.3) \
itr200: (train/val) los:1.801/1.979 acc:0.370/0.350 spa:0.600 (t:1.2) \
itr300: (train/val) los:1.622/1.603 acc:0.460/0.410 spa:0.600 (t:1.2) \
itr400: (train/val) los:1.576/1.700 acc:0.460/0.380 spa:0.600 (t:1.2) \
itr500: (train/val) los:1.630/1.792 acc:0.500/0.410 spa:0.600 (t:1.2) \
itr600: (train/val) los:1.513/1.749 acc:0.540/0.450 spa:0.600 (t:1.2) \
itr700: (train/val) los:1.683/1.450 acc:0.440/0.550 spa:0.600 (t:1.2) \
itr800: (train/val) los:1.480/1.773 acc:0.510/0.390 spa:0.600 (t:1.2) \
itr900: (train/val) los:1.568/1.577 acc:0.430/0.440 spa:0.600 (t:1.2) \
itr1000: (train/val) los:1.437/1.706 acc:0.550/0.400 spa:0.600 (t:1.2) \
itr1100: (train/val) los:1.368/1.324 acc:0.550/0.520 spa:0.600 (t:1.2) \
itr1200: (train/val) los:1.314/1.624 acc:0.580/0.410 spa:0.600 (t:1.2) \
itr1300: (train/val) los:1.323/1.394 acc:0.610/0.510 spa:0.600 (t:1.2) \
itr1400: (train/val) los:1.295/1.581 acc:0.590/0.450 spa:0.600 (t:1.2) \
itr1500: (train/val) los:1.230/1.521 acc:0.600/0.420 spa:0.600 (t:1.2) \
itr1600: (train/val) los:1.401/1.473 acc:0.580/0.500 spa:0.600 (t:1.2) \
itr1700: (train/val) los:1.437/1.657 acc:0.540/0.340 spa:0.600 (t:1.2) \
itr1800: (train/val) los:1.291/1.572 acc:0.600/0.520 spa:0.600 (t:1.2) \
itr1900: (train/val) los:1.301/1.643 acc:0.610/0.460 spa:0.600 (t:1.2) \
itr2000: (train/val) los:1.382/1.669 acc:0.510/0.500 spa:0.600 (t:1.2) \
itr2100: (train/val) los:1.387/1.704 acc:0.530/0.400 spa:0.600 (t:1.2) \
itr2200: (train/val) los:1.356/1.399 acc:0.530/0.490 spa:0.600 (t:1.2) \
itr2300: (train/val) los:1.077/1.329 acc:0.670/0.550 spa:0.600 (t:1.2) \
itr2400: (train/val) los:1.212/1.443 acc:0.580/0.590 spa:0.600 (t:1.2) \
itr2500: (train/val) los:1.284/1.546 acc:0.590/0.500 spa:0.600 (t:1.2) \
itr2600: (train/val) los:1.375/1.594 acc:0.550/0.390 spa:0.600 (t:1.2) \
itr2700: (train/val) los:1.264/1.489 acc:0.550/0.550 spa:0.600 (t:1.2) \
itr2800: (train/val) los:1.356/1.711 acc:0.530/0.420 spa:0.600 (t:1.2) \
itr2900: (train/val) los:1.324/1.460 acc:0.630/0.510 spa:0.600 (t:1.2) \
itr3000: (train/val) los:1.272/1.626 acc:0.600/0.530 spa:0.600 (t:1.2) \
itr3100: (train/val) los:1.193/1.433 acc:0.580/0.450 spa:0.600 (t:1.2) \
itr3200: (train/val) los:1.346/1.622 acc:0.500/0.480 spa:0.600 (t:1.2) \
itr3300: (train/val) los:1.428/1.618 acc:0.570/0.500 spa:0.600 (t:1.2) \
itr3400: (train/val) los:1.267/1.284 acc:0.590/0.480 spa:0.600 (t:1.2) \
itr3500: (train/val) los:1.231/1.486 acc:0.610/0.500 spa:0.600 (t:1.2) \
itr3600: (train/val) los:1.189/1.577 acc:0.620/0.490 spa:0.600 (t:1.2) \
itr3700: (train/val) los:1.217/1.782 acc:0.640/0.460 spa:0.600 (t:1.2) \
itr3800: (train/val) los:1.037/1.462 acc:0.640/0.520 spa:0.600 (t:1.2) \
itr3900: (train/val) los:0.991/1.454 acc:0.700/0.490 spa:0.600 (t:1.2) \
itr4000: (train/val) los:1.123/1.571 acc:0.640/0.510 spa:0.600 (t:1.2) \
itr4100: (train/val) los:1.204/1.335 acc:0.650/0.570 spa:0.600 (t:1.2) \
itr4200: (train/val) los:1.351/1.398 acc:0.580/0.600 spa:0.600 (t:1.2) \
itr4300: (train/val) los:1.180/1.693 acc:0.590/0.450 spa:0.600 (t:1.2) \
itr4400: (train/val) los:1.038/1.793 acc:0.690/0.480 spa:0.600 (t:1.2) \
itr4500: (train/val) los:1.155/1.780 acc:0.640/0.460 spa:0.600 (t:1.2) \
itr4600: (train/val) los:0.994/1.402 acc:0.690/0.580 spa:0.600 (t:1.2) \
itr4700: (train/val) los:1.354/1.592 acc:0.580/0.500 spa:0.600 (t:1.2) \
itr4800: (train/val) los:1.111/1.487 acc:0.660/0.530 spa:0.600 (t:1.2) \
itr4900: (train/val) los:1.188/1.599 acc:0.600/0.520 spa:0.600 (t:1.2) \
itr5000: (train/val) los:0.970/1.282 acc:0.650/0.600 spa:0.600 (t:1.2) \
itr5100: (train/val) los:1.018/1.547 acc:0.680/0.550 spa:0.600 (t:1.2) \
itr5200: (train/val) los:1.229/1.510 acc:0.570/0.530 spa:0.600 (t:1.2) \
itr5300: (train/val) los:1.442/2.057 acc:0.620/0.490 spa:0.600 (t:1.2) \
itr5400: (train/val) los:1.289/1.734 acc:0.600/0.450 spa:0.600 (t:1.2) \
itr5500: (train/val) los:1.140/1.497 acc:0.630/0.450 spa:0.600 (t:1.2) \
itr5600: (train/val) los:1.260/1.450 acc:0.650/0.500 spa:0.600 (t:1.2) \
itr5700: (train/val) los:1.020/1.549 acc:0.730/0.520 spa:0.600 (t:1.2) \
itr5800: (train/val) los:1.002/1.551 acc:0.700/0.440 spa:0.600 (t:1.2) \
itr5900: (train/val) los:0.970/1.723 acc:0.700/0.500 spa:0.600 (t:1.2) \
itr6000: (train/val) los:0.910/1.823 acc:0.750/0.480 spa:0.600 (t:1.2) \
itr6100: (train/val) los:0.844/1.616 acc:0.720/0.610 spa:0.600 (t:1.2) \
itr6200: (train/val) los:1.228/1.559 acc:0.590/0.530 spa:0.600 (t:1.1) \
itr6300: (train/val) los:1.250/1.625 acc:0.590/0.580 spa:0.600 (t:1.2) \
itr6400: (train/val) los:1.030/1.413 acc:0.630/0.550 spa:0.600 (t:1.2) \
itr6500: (train/val) los:0.951/1.522 acc:0.720/0.530 spa:0.600 (t:1.2) \
itr6600: (train/val) los:1.052/1.766 acc:0.630/0.460 spa:0.600 (t:1.2) \
itr6700: (train/val) los:1.000/1.728 acc:0.700/0.530 spa:0.600 (t:1.2) \
itr6800: (train/val) los:0.799/1.557 acc:0.770/0.540 spa:0.600 (t:1.2) \
itr6900: (train/val) los:0.887/1.509 acc:0.730/0.560 spa:0.600 (t:1.2) \
itr7000: (train/val) los:1.004/1.507 acc:0.660/0.570 spa:0.600 (t:1.2) \
itr7100: (train/val) los:1.433/1.955 acc:0.580/0.520 spa:0.600 (t:1.2) \
itr7200: (train/val) los:0.925/1.629 acc:0.740/0.580 spa:0.600 (t:1.2) \
itr7300: (train/val) los:0.971/1.954 acc:0.680/0.370 spa:0.600 (t:1.2) \
itr7400: (train/val) los:0.874/1.534 acc:0.770/0.630 spa:0.600 (t:1.2) \
itr7500: (train/val) los:0.979/2.145 acc:0.690/0.430 spa:0.600 (t:1.2) \
itr7600: (train/val) los:0.997/1.631 acc:0.730/0.550 spa:0.600 (t:1.2) \
itr7700: (train/val) los:0.851/1.981 acc:0.720/0.490 spa:0.600 (t:1.2) \
itr7800: (train/val) los:0.933/1.649 acc:0.720/0.490 spa:0.600 (t:1.2) \
itr7900: (train/val) los:0.781/1.654 acc:0.770/0.520 spa:0.600 (t:1.2) \
itr8000: (train/val) los:0.971/1.904 acc:0.720/0.470 spa:0.600 (t:1.2) \
itr8100: (train/val) los:0.895/1.696 acc:0.740/0.490 spa:0.600 (t:1.2) \
itr8200: (train/val) los:1.151/2.167 acc:0.600/0.410 spa:0.600 (t:1.2) \
itr8300: (train/val) los:1.029/1.665 acc:0.720/0.510 spa:0.600 (t:1.2) \
itr8400: (train/val) los:0.766/1.793 acc:0.770/0.530 spa:0.600 (t:1.2) \
itr8500: (train/val) los:0.842/2.072 acc:0.750/0.410 spa:0.600 (t:1.2) \
itr8600: (train/val) los:0.789/1.422 acc:0.770/0.600 spa:0.600 (t:1.2) \
itr8700: (train/val) los:0.931/2.075 acc:0.750/0.500 spa:0.600 (t:1.2) \
itr8800: (train/val) los:0.974/1.908 acc:0.700/0.470 spa:0.600 (t:1.2) \
itr8900: (train/val) los:1.076/2.065 acc:0.680/0.450 spa:0.600 (t:1.2) \
itr9000: (train/val) los:0.845/2.164 acc:0.750/0.440 spa:0.600 (t:1.2) \
itr9100: (train/val) los:0.832/1.874 acc:0.760/0.510 spa:0.600 (t:1.2) \
itr9200: (train/val) los:1.024/1.826 acc:0.700/0.520 spa:0.600 (t:1.2) \
itr9300: (train/val) los:0.844/1.827 acc:0.770/0.470 spa:0.600 (t:1.2) \
itr9400: (train/val) los:1.013/1.803 acc:0.720/0.510 spa:0.600 (t:1.2) \
itr9500: (train/val) los:0.858/2.038 acc:0.760/0.500 spa:0.600 (t:1.2) \
itr9600: (train/val) los:1.070/2.181 acc:0.710/0.470 spa:0.600 (t:1.2) \
itr9700: (train/val) los:0.988/1.999 acc:0.670/0.460 spa:0.600 (t:1.2) \
itr9800: (train/val) los:0.900/1.989 acc:0.710/0.480 spa:0.600 (t:1.2) \
itr9900: (train/val) los:0.937/1.953 acc:0.720/0.480 spa:0.600 (t:1.2) \
itr10000: (train/val) los:0.843/2.022 acc:0.760/0.530 spa:0.600 (t:1.2)',
'itr100: (train/val) los:1.814/1.783 acc:0.370/0.390 spa:0.601 (t:1.3) \
itr200: (train/val) los:1.785/1.951 acc:0.350/0.340 spa:0.601 (t:1.2) \
itr300: (train/val) los:1.577/1.597 acc:0.480/0.430 spa:0.601 (t:1.2) \
itr400: (train/val) los:1.534/1.674 acc:0.450/0.360 spa:0.601 (t:1.2) \
itr500: (train/val) los:1.610/1.755 acc:0.500/0.410 spa:0.601 (t:1.2) \
itr600: (train/val) los:1.534/1.732 acc:0.490/0.420 spa:0.601 (t:1.2) \
itr700: (train/val) los:1.657/1.437 acc:0.420/0.550 spa:0.601 (t:1.2) \
itr800: (train/val) los:1.495/1.757 acc:0.480/0.330 spa:0.601 (t:1.2) \
itr900: (train/val) los:1.583/1.575 acc:0.440/0.460 spa:0.601 (t:1.2) \
itr1000: (train/val) los:1.387/1.729 acc:0.600/0.350 spa:0.601 (t:1.2) \
itr1100: (train/val) los:1.361/1.286 acc:0.550/0.550 spa:0.601 (t:1.2) \
itr1200: (train/val) los:1.299/1.631 acc:0.550/0.470 spa:0.601 (t:1.2) \
itr1300: (train/val) los:1.384/1.450 acc:0.500/0.530 spa:0.601 (t:1.2) \
itr1400: (train/val) los:1.277/1.578 acc:0.580/0.440 spa:0.601 (t:1.2) \
itr1500: (train/val) los:1.255/1.514 acc:0.590/0.480 spa:0.601 (t:1.2) \
itr1600: (train/val) los:1.403/1.418 acc:0.580/0.530 spa:0.601 (t:1.2) \
itr1700: (train/val) los:1.379/1.692 acc:0.500/0.350 spa:0.601 (t:1.2) \
itr1800: (train/val) los:1.268/1.577 acc:0.620/0.510 spa:0.601 (t:1.2) \
itr1900: (train/val) los:1.304/1.610 acc:0.590/0.480 spa:0.601 (t:1.2) \
itr2000: (train/val) los:1.325/1.588 acc:0.530/0.480 spa:0.601 (t:1.2) \
itr2100: (train/val) los:1.423/1.724 acc:0.540/0.460 spa:0.601 (t:1.2) \
itr2200: (train/val) los:1.385/1.406 acc:0.520/0.490 spa:0.601 (t:1.2) \
itr2300: (train/val) los:1.069/1.402 acc:0.630/0.500 spa:0.601 (t:1.2) \
itr2400: (train/val) los:1.213/1.465 acc:0.570/0.620 spa:0.601 (t:1.2) \
itr2500: (train/val) los:1.355/1.572 acc:0.590/0.470 spa:0.601 (t:1.2) \
itr2600: (train/val) los:1.385/1.540 acc:0.540/0.440 spa:0.601 (t:1.2) \
itr2700: (train/val) los:1.383/1.494 acc:0.520/0.520 spa:0.601 (t:1.2) \
itr2800: (train/val) los:1.345/1.713 acc:0.540/0.410 spa:0.601 (t:1.2) \
itr2900: (train/val) los:1.328/1.382 acc:0.580/0.540 spa:0.601 (t:1.2) \
itr3000: (train/val) los:1.315/1.652 acc:0.560/0.490 spa:0.601 (t:1.2) \
itr3100: (train/val) los:1.213/1.517 acc:0.620/0.480 spa:0.601 (t:1.2) \
itr3200: (train/val) los:1.375/1.585 acc:0.550/0.510 spa:0.601 (t:1.2) \
itr3300: (train/val) los:1.388/1.512 acc:0.560/0.490 spa:0.601 (t:1.2) \
itr3400: (train/val) los:1.269/1.314 acc:0.570/0.550 spa:0.601 (t:1.2) \
itr3500: (train/val) los:1.274/1.660 acc:0.590/0.480 spa:0.601 (t:1.2) \
itr3600: (train/val) los:1.153/1.682 acc:0.640/0.480 spa:0.601 (t:1.2) \
itr3700: (train/val) los:1.111/1.663 acc:0.640/0.500 spa:0.601 (t:1.2) \
itr3800: (train/val) los:1.015/1.474 acc:0.680/0.490 spa:0.601 (t:1.2) \
itr3900: (train/val) los:0.930/1.575 acc:0.720/0.450 spa:0.601 (t:1.2) \
itr4000: (train/val) los:1.148/1.563 acc:0.650/0.490 spa:0.601 (t:1.2) \
itr4100: (train/val) los:1.151/1.367 acc:0.630/0.550 spa:0.601 (t:1.2) \
itr4200: (train/val) los:1.305/1.380 acc:0.540/0.530 spa:0.601 (t:1.2) \
itr4300: (train/val) los:1.216/1.683 acc:0.600/0.430 spa:0.601 (t:1.2) \
itr4400: (train/val) los:1.143/1.694 acc:0.650/0.460 spa:0.601 (t:1.2) \
itr4500: (train/val) los:1.149/1.721 acc:0.640/0.460 spa:0.601 (t:1.2) \
itr4600: (train/val) los:1.054/1.491 acc:0.640/0.570 spa:0.601 (t:1.2) \
itr4700: (train/val) los:1.340/1.587 acc:0.620/0.530 spa:0.601 (t:1.2) \
itr4800: (train/val) los:1.130/1.453 acc:0.630/0.590 spa:0.601 (t:1.2) \
itr4900: (train/val) los:1.139/1.577 acc:0.590/0.580 spa:0.601 (t:1.2) \
itr5000: (train/val) los:1.112/1.341 acc:0.610/0.570 spa:0.601 (t:1.2) \
itr5100: (train/val) los:1.039/1.578 acc:0.660/0.540 spa:0.601 (t:1.2) \
itr5200: (train/val) los:1.338/1.651 acc:0.560/0.390 spa:0.601 (t:1.2) \
itr5300: (train/val) los:1.460/1.946 acc:0.610/0.490 spa:0.601 (t:1.2) \
itr5400: (train/val) los:1.127/1.511 acc:0.650/0.530 spa:0.601 (t:1.2) \
itr5500: (train/val) los:1.088/1.523 acc:0.710/0.490 spa:0.601 (t:1.2) \
itr5600: (train/val) los:1.165/1.516 acc:0.640/0.500 spa:0.601 (t:1.2) \
itr5700: (train/val) los:1.162/1.764 acc:0.640/0.500 spa:0.601 (t:1.2) \
itr5800: (train/val) los:0.994/1.557 acc:0.740/0.490 spa:0.601 (t:1.2) \
itr5900: (train/val) los:0.997/1.830 acc:0.690/0.450 spa:0.601 (t:1.2) \
itr6000: (train/val) los:1.008/1.696 acc:0.700/0.530 spa:0.601 (t:1.2) \
itr6100: (train/val) los:0.941/1.570 acc:0.710/0.560 spa:0.601 (t:1.2) \
itr6200: (train/val) los:1.287/1.546 acc:0.610/0.570 spa:0.601 (t:1.2) \
itr6300: (train/val) los:1.270/1.484 acc:0.640/0.540 spa:0.601 (t:1.2) \
itr6400: (train/val) los:1.010/1.519 acc:0.680/0.540 spa:0.601 (t:1.2) \
itr6500: (train/val) los:1.021/1.662 acc:0.660/0.490 spa:0.601 (t:1.2) \
itr6600: (train/val) los:1.007/1.798 acc:0.660/0.460 spa:0.601 (t:1.2) \
itr6700: (train/val) los:1.079/1.827 acc:0.630/0.470 spa:0.601 (t:1.2) \
itr6800: (train/val) los:0.841/1.467 acc:0.750/0.540 spa:0.601 (t:1.2) \
itr6900: (train/val) los:1.002/1.531 acc:0.720/0.550 spa:0.601 (t:1.2) \
itr7000: (train/val) los:0.992/1.567 acc:0.690/0.550 spa:0.601 (t:1.2) \
itr7100: (train/val) los:1.247/1.795 acc:0.620/0.500 spa:0.601 (t:1.2) \
itr7200: (train/val) los:1.036/1.548 acc:0.750/0.610 spa:0.601 (t:1.2) \
itr7300: (train/val) los:1.015/1.969 acc:0.680/0.400 spa:0.601 (t:1.2) \
itr7400: (train/val) los:0.845/1.701 acc:0.750/0.490 spa:0.601 (t:1.2) \
itr7500: (train/val) los:0.787/2.014 acc:0.790/0.470 spa:0.601 (t:1.2) \
itr7600: (train/val) los:1.046/1.578 acc:0.660/0.560 spa:0.601 (t:1.2) \
itr7700: (train/val) los:1.019/1.832 acc:0.690/0.460 spa:0.601 (t:1.2) \
itr7800: (train/val) los:0.905/1.666 acc:0.710/0.480 spa:0.601 (t:1.2) \
itr7900: (train/val) los:0.850/1.708 acc:0.740/0.480 spa:0.601 (t:1.2) \
itr8000: (train/val) los:1.030/2.040 acc:0.620/0.430 spa:0.601 (t:1.2) \
itr8100: (train/val) los:0.822/1.750 acc:0.770/0.460 spa:0.601 (t:1.2) \
itr8200: (train/val) los:0.870/2.016 acc:0.700/0.440 spa:0.601 (t:1.2) \
itr8300: (train/val) los:0.917/1.652 acc:0.750/0.520 spa:0.601 (t:1.2) \
itr8400: (train/val) los:0.917/1.641 acc:0.750/0.470 spa:0.601 (t:1.2) \
itr8500: (train/val) los:0.868/1.887 acc:0.740/0.490 spa:0.601 (t:1.2) \
itr8600: (train/val) los:0.775/1.382 acc:0.780/0.640 spa:0.601 (t:1.2) \
itr8700: (train/val) los:1.127/2.546 acc:0.640/0.420 spa:0.601 (t:1.2) \
itr8800: (train/val) los:0.747/1.718 acc:0.800/0.570 spa:0.601 (t:1.2) \
itr8900: (train/val) los:0.920/1.935 acc:0.730/0.490 spa:0.601 (t:1.2) \
itr9000: (train/val) los:1.077/2.196 acc:0.680/0.450 spa:0.601 (t:1.2) \
itr9100: (train/val) los:0.940/1.923 acc:0.730/0.450 spa:0.601 (t:1.2) \
itr9200: (train/val) los:1.040/1.815 acc:0.680/0.510 spa:0.601 (t:1.2) \
itr9300: (train/val) los:0.926/1.949 acc:0.730/0.470 spa:0.601 (t:1.2) \
itr9400: (train/val) los:1.049/1.855 acc:0.730/0.520 spa:0.601 (t:1.2) \
itr9500: (train/val) los:0.895/2.116 acc:0.730/0.490 spa:0.601 (t:1.2) \
itr9600: (train/val) los:0.930/1.992 acc:0.730/0.510 spa:0.601 (t:1.2) \
itr9700: (train/val) los:0.972/2.101 acc:0.690/0.480 spa:0.601 (t:1.2) \
itr9800: (train/val) los:0.857/1.680 acc:0.770/0.490 spa:0.601 (t:1.2) \
itr9900: (train/val) los:1.033/1.853 acc:0.730/0.420 spa:0.601 (t:1.2) \
itr10000: (train/val) los:0.847/2.075 acc:0.780/0.460 spa:0.601 (t:1.2)']

# %%
accs_tr_rnd_mask = []
accs_ts_rnd_mask = []
for mask in train_snip_mask + train_random_mask:
    tmp_tr = []
    tmp_ts = []
    for e in mask.split():
        if e[:3] == 'acc':
            tmp_tr.append(float(e[4:9]))
            tmp_ts.append(float(e[10:15]))
    accs_tr_rnd_mask.append(tmp_tr)
    accs_ts_rnd_mask.append(tmp_ts)
print(accs_tr_rnd_mask)
# Out:
# [[0.36, 0.49, 0.38, 0.44, 0.44, 0.48, 0.59, 0.42, 0.5, 0.49, 0.48, 0.55, 0.56, 0.58, 0.55, 0.53, 0.54, 0.57, 0.53, 0.6, 0.59, 0.59, 0.53, 0.57, 0.61, 0.59, 0.55, 0.67, 0.56, 0.52, 0.67, 0.57, 0.6, 0.53, 0.66, 0.67, 0.63, 0.53, 0.62, 0.61, 0.52, 0.6, 0.6, 0.63, 0.69, 0.63, 0.7, 0.66, 0.62, 0.66, 0.69, 0.66, 0.6, 0.73, 0.64, 0.66, 0.72, 0.69, 0.79, 0.81, 0.75, 0.68, 0.64, 0.7, 0.71, 0.65, 0.63, 0.73, 0.75, 0.68, 0.78, 0.79, 0.71, 0.74, 0.68, 0.74, 0.71, 0.69, 0.71, 0.71, 0.82, 0.74, 0.75, 0.73, 0.64, 0.78, 0.75, 0.78, 0.69, 0.77, 0.76, 0.73, 0.71, 0.7, 0.78, 0.75, 0.76, 0.79, 0.71, 0.78], [0.38, 0.47, 0.34, 0.42, 0.52, 0.45, 0.58, 0.41, 0.48, 0.53, 0.5, 0.5, 0.55, 0.61, 0.55, 0.51, 0.57, 0.52, 0.57, 0.58, 0.54, 0.49, 0.56, 0.68, 0.55, 0.56, 0.56, 0.61, 0.6, 0.47, 0.61, 0.61, 0.62, 0.55, 0.62, 0.69, 0.68, 0.51, 0.59, 0.67, 0.54, 0.57, 0.58, 0.54, 0.68, 0.59, 0.65, 0.72, 0.61, 0.72, 0.65, 0.65, 0.65, 0.69, 0.7, 0.7, 0.63, 0.72, 0.79, 0.7, 0.78, 0.67, 0.64, 0.71, 0.73, 0.66, 0.64, 0.74, 0
# ...

# %%
plt.figure(figsize=(12,10))
line = ['-']*2 + ['--']*2
for idx, mask in enumerate(accs_tr_rnd_mask):
    plt.plot([i*100 for i in range(1, len(mask) + 1)], mask, line[idx], alpha=0.5)
plt.title('lenet300, CIFAR, sparsity 0.6, variance scaling')
# Out:
# Text(0.5, 1.0, 'lenet300, CIFAR, sparsity 0.6, variance scaling')

# %%
plt.figure(figsize=(12,10))
line = ['-']*2 + ['--']*2
for idx, mask in enumerate(accs_ts_rnd_mask):
    plt.plot([i*100 for i in range(1, len(mask) + 1)], mask, line[idx], alpha=0.5)
plt.title('lenet300, CIFAR, sparsity 0.6, variance scaling')
# Out:
# Text(0.5, 1.0, 'lenet300, CIFAR, sparsity 0.6, variance scaling')

# %%
intersection_real = []
for i in np.random.randint(1000, size=60):
    for j in np.random.randint(1000, size = 30):
        intersection = 0
        for w in ['w1', 'w2', 'w3']:
            intersection += np.sum(dicts[j][w] * dicts[i][w])
        intersection /= total_elems
        intersection_real.append(intersection)
        
intersection_random = []
for i in np.random.randint(1000, size=400):
    intersection = 0
    random_mask = {}
    random_mask['w1'] = np.random.choice(2, p=[0.9, 0.1], size=dicts[0]['w1'].shape).astype(np.float32)
    random_mask['w2'] = np.random.choice(2, p=[0.9, 0.1], size=dicts[0]['w2'].shape).astype(np.float32)
    random_mask['w3'] = np.random.choice(2, p=[0.9, 0.1], size=dicts[0]['w3'].shape).astype(np.float32)

    random_mask['b1'] = dicts[0]['b1']
    random_mask['b2'] = dicts[0]['b2']
    random_mask['b3'] = dicts[0]['b3']    
    
    random_mask2 = {}
    random_mask2['w1'] = np.random.choice(2, p=[0.9, 0.1], size=dicts[0]['w1'].shape).astype(np.float32)
    random_mask2['w2'] = np.random.choice(2, p=[0.9, 0.1], size=dicts[0]['w2'].shape).astype(np.float32)
    random_mask2['w3'] = np.random.choice(2, p=[0.9, 0.1], size=dicts[0]['w3'].shape).astype(np.float32)

    random_mask2['b1'] = dicts[0]['b1']
    random_mask2['b2'] = dicts[0]['b2']
    random_mask2['b3'] = dicts[0]['b3']
    for w in ['w1', 'w2', 'w3']:
        intersection += np.sum(random_mask[w] * random_mask2[w])
    intersection /= total_elems
    intersection_random.append(intersection)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-c7e3144d30d4> in <module>
#       4         intersection = 0
#       5         for w in ['w1', 'w2', 'w3']:
# ----> 6             intersection += np.sum(dicts[j][w] * dicts[i][w])
#       7         intersection /= total_elems
#       8         intersection_real.append(intersection)
#
# NameError: name 'dicts' is not defined

# %%
np.mean(intersection_real)
# Out:
# 0.027156018866349444

# %%
np.mean(intersection_random)
# Out:
# 0.010002451164537941

# %%
tmp1 = np.random.choice(2, size=(5,7))
tmp2 = np.random.choice(2, size=(5,7))
tmp1==tmp2 * tmp1
# Out:
# array([[ True,  True, False,  True, False,  True, False],
#        [ True, False, False, False, False,  True,  True],
#        [ True,  True,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True, False,  True],
#        [ True, False, False,  True,  True,  True,  True]])

# %%
plt.figure(figsize=(20,20))
plt.imshow(random_mask['w1'], cmap='hot')
